# %%
import pandas as pd
import jieba
import codecs
import numpy as np
from gensim import models
# 保存/导入model
from sklearn.externals import joblib
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import precision_score, recall_score
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

cut_all = models.Word2Vec.load('./model/cut_all.model')
model = models.Word2Vec.load('./model/finance.model')
model2 = models.Word2Vec.load('./model/finance2.model')

# %%
stop_words = ''.join(codecs.open('./input/stop_words.txt', encoding='utf-8').readlines()).split('\n')

# %%
def tfidf_processing(sentence, label, stop_words=[], test_size=0.1):
    X_train, X_test, y_train, y_test = train_test_split(sentence, label, test_size=test_size, random_state=33)
    s = pd.Series(X_test)
    s.to_csv('./X_test.csv', index=False)
    X_train = [' '.join(jieba.cut(x_train)) for x_train in X_train]
    X_test = [' '.join(jieba.cut(x_test)) for x_test in X_test]
    tfidf = TfidfVectorizer(token_pattern=r"(?u)\b\w+\b")
    X_train = tfidf.fit_transform(X_train)
    X_test = tfidf.transform(X_test)
    joblib.dump(tfidf, './model/tfidf_model.pkl', compress=3)
    return X_train, X_test, y_train, y_test

# %%
def w2v_processing(sentence, label, test_size=0.1):
    X_train, X_test, y_train, y_test = train_test_split(sentence, label, test_size=test_size, random_state=33)
    X_train = np.array([get_vec(str(s), model) for s in X_train])
    X_test = np.array([get_vec(str(s), model) for s in X_test])
    print('w2v done...')
    return X_train, X_test, y_train, y_test

# %%
def get_vec(sentence, model):
    vec = np.zeros(model.vector_size)
    n = 0
    for word in jieba.cut(sentence):
        try:
            vec += model.wv[word]
            n += 1
        except KeyError:
            pass
    return vec if n==0 else vec/n 

# 需要加异常处理
def sentence_vector(s, model):
        words = jieba.lcut(s)
        v = np.zeros(100)
        for word in words:
            v += model[word]
        v /= len(words)
        return v

# %%
def random_forest(X_train, X_test, y_train, y_test):
    print("训练样本 = %d" % len(y_train))
    print("测试样本 = %d" % len(y_test))

    clf = RandomForestClassifier(n_estimators=2000, max_depth=80 , n_jobs=6)  
    nn = clf.fit(X_train, y_train)
    joblib.dump(nn, './model/random_forest.pkl', compress=3)
    y_predict = clf.predict(X_test)
    
    predict = pd.DataFrame({'y_test': y_test, 'y_predict': y_predict})
    return nn, predict

# %%
def svm(X_train, X_test, y_train, y_test):
    print("训练样本 = %d" % len(y_train))
    print("测试样本 = %d" % len(y_test))
    
    clf =

# %%
def metrics_(predict):
    y_true = predict['y_test']
    y_pred = predict['y_predict']
    pre = precision_score(y_true, y_pred, average='binary')
    recall = recall_score(y_true, y_pred, average='binary')
    print('-' * 50)
    print('准确率：' + str(pre) + '\n召回率：' + str(recall))

# %% [markdown]
# # 数据预处理

# %%
df = pd.read_csv(r'G:\BaiduNetdiskDownload/financezhidao_filter.csv').fillna('')

# %%
df.sample(5)
# Out:
#                                title                      question  \
# 24238   2018年我是湖*人在广*有住房公积金可以到重*买房吗?  2018年我是湖*人在广*有住房公积金可以到重*买房吗?
# 72161                    信用度不好怎么才能贷款
# 92528             我在网上申请小额贷款为什么总是被拒绝
# 73572    我有固定工作,有工资卡,身份证,如何快速借款500元?
# 603939                    网上小额贷款可靠吗？
#
#                                                 reply  is_best
# 24238   各地公积金政策有所不同，建议通过官网查询或者咨询当地公积金管理中心，官方电话是12#29.        1
# 72161                                          贷多钱~~？        0
# 92528                                            想贷多少        0
# 73572                                       qq微信淘宝都可以        0
# 603939                        正规的会越来越多，必要的时候你多问问身边的人。        0

# %%
df = pd.read_csv('./input/corpus.csv').fillna('')
l = list((df.topic.value_counts() > 5).to_dict().keys())
df = df[df['topic'].isin(l)]

# %%
df[df['topic'] == '电影']
# Out:
#         answer_id                                      answerer_tags  \
# 5        39769445
# 190      34382979
# 208      95913044                                    热爱这个丑陋世界的人才是真善美
# 225      68841371  前端程序员 Web开发者 吉他爱好者 个人微信号:posebear1990 微信公众号: i...
# 237      73250275                                               膜力宝贝
# 365      92706006                                 地理，经济，麻类植物爱好者，研究人员
# 412      56364331                                    为lgbt平权，男女平权而努力
# 484     115698780                               一个不知道怎么写自我介绍的共产主义接班人
# 599     135981902                                              典型水瓶座
# 623     126666160                                             东叶寺 鞭巨
# 629      42745712                                             电影爱好者~
# 640      70234295                                         目成心许，至死靡它。
# 705      53108087                                          除了经济什么都喜欢
# 729      50713426
# 768     126661853
# 793     107798365                                膜你mb！无聊当有趣。看一个举报一个。
# 800      52038756                                       城市的魅力。美丽的城市。
# 874      28030511                                    间歇性精神病，偶尔会正常一下。
# 935     185401785                                         一名不谈民谣的吉他手
# 993      50133983
# 1002    181137614                                            落魄的王子殿下
# 1131     72604906
# 1152     29091274                                       而或长烟一空，皓月千里。
# 1171     75756343                                             按快门和撸猫
# 1212    137892047                                             男的，影视狗
# 1224    168791324                                             通信工程在读
# 1245     34381716                                          头像本人/不玩SM
# 1252    148722949                                广告犬、文案汪、脱口秀爱好者、国足球迷
# 1262     38006883
# 1281    199708364                                                 学生
# ...           ...                                                ...
# 135602   23667300                                            职业职教学生。
# 135607   86824975
# 135623  164126846                                        松鼠症患者，资源收集狂
# 135651  104001939                      会计 ACCA learning BBOXer Dota2
# 135671  172876200                    大学生 普通人 低谷期 逆流而上 心理专业留学生 SCP基金会
# 135730  188342536                                            我不认识李雷！
# 135917   91166032                      淘宝店铺号14152020床品特价包邮。v：yibofen
# 136033   37064274                                               荣辱不惊
# 136094   58068688                                             没所谓爱好者
# 136097  137361406
# 136101   70117178                              没有参考答案就下不了笔的人，最好还是搬砖。
# 136116  122188288
# 136130   87547367
# 136155   81848889                                             和自己对话。
# 136334   66415286                                              选择恐惧症
# 136335  120358789                                                 婚礼
# 136367  199365893                     ⚠ 系统提示：检测到timeline二级污染源，请谨慎关注！
# 136374  118475371
# 136375  150942656
# 136424   15138254                                     行解相应，能够利人，便是利已
# 136433  110312621                                              建筑设计汪
# 136443   80360210                                        全能的小王。助人为乐。
# 136444   90909679                            最好沒有人明白我在說什麼，只有你聽懂我在想什麼
# 136453   15646633                                               纠结的人
# 136596   37806840
# 136610  149976397                                          公众号：银幕筛查机
# 136623   89853092                   聚若浮萍散若云，穷通寿夭俱莫问。绮陌红楼应笑我，素华流年不待君。
# 136634  153579784
# 136640   69918059                             专业造轮子，拉黑抢前排。gaclib.net
# 136658  167797578                                          研究控+八卦爱好者
#
#                                                   content  \
# 5       美漫里除了有滥情或者花少属性的个别人物之外，大都cp是比较稳定的，很少性生活混乱的情况。因为...
# 190     我记得有人写过一个，回去发链接。事先说下，我只是转载的，喜欢的同学可以点最后的链接，有更完g...
# 208     肖恩宾 Sean Bean，绰号人形自走剧透机，一直在死的男人，因为他演的大部分角色都是配角...
# 225     卢正雨 补充一点： 说实话，周星驰的牛逼之处在于，周星驰之后是绝对是再无周星驰的。而且，我说...
# 237                             糟点太多了，抓到邦德一枪蹦了，什么BUG都没有了。
# 365     有一个关于大麻的彩蛋很有意思。yax在电影中是一只崇尚自然主义的动物，而扮演者不是别人，正是...
# 412     有个简单评判办法关掉声音，没有了配音和背景乐，演员的口型好看不？眼精有神不？他她是用什么来演...
# 484     以下内容涉及毫无看点的剧透，且仅代表个人观点 看完夏有乔木雅望天堂了我快要吐血身亡了感觉身体...
# 599     应该是动之以情，晓之以理。泷属于暴力强迫型，男人之间碰撞，当然是硬碰硬不欢而散。而作为柔软的...
# 623     从不敢奢求能完全理解一部电影，严肃脸 因为一旦提到理解，就是一件多维度多因素的事情。从内在的...
# 629                                    你好陌生人泰国的一部很温馨的爱情电影
# 640     伊甸湖。没有人提名伊甸湖吗？从头到尾都是满满的恶意。从开始到最后，最后的最后，最后的最后，都...
# 705                       小学看的纸飞机一部国产电影，会哭，是因为主人公的故事与我相似唉
# 729                                              张国荣所有的片子
# 768     每一次一个烂片票房低了，人们就会说果然大众还是有分辨能力的，拍烂片就是得失败。然后没过多久就...
# 793                                          哈利波特长成了霍比特人。
# 800     芝加哥 豆瓣 福禄双霸天 豆瓣 春天不是读书天 豆瓣 亡命天涯 豆瓣 当哈利遇到莎莉 豆瓣 ...
# 874     小田切让 帅到可以让我弯。可以古装 可以时装 混搭也没问题 正装也轻松HOLD住 经常尝试百...
# 935     有钱的人不知道，但是摇滚明星的知道不少，稍微说一下吧。其实吸毒最凶的大概就是上个世纪的摇滚明...
# 993     我外公，迄今为止已经看了70多部抗日神剧了，基本上是从优酷上在线看的，一部分是表妹给他下载看...
# 1002                                           你对cos一无所知。
# 1131    我看过那么多柯南和福尔摩斯，但前两天我弟弟一次有组织有目的跨越时间维度的一次推理，让我觉我这...
# 1152    缅怀彼得也许这个题目不对，我记得最早认识Peter Pan就是看罗宾的Hook，斯皮尔伯格导...
# 1171             谢邀 “人总是不由自主地说起家乡话，一是很不爽的时候，一是很爽的时候” 战争之王
# 1212    我的年度十佳，只代表个人庸俗的品味，不代表任何立场，不喜勿喷。今年没有出国参加电影节，所有片...
# 1224    整件事情我觉得特别大的震动就是：这些流量小花小草对现在的年轻人的荼毒。5月11日，我在QQ新...
# 1245                                  当手淫失去了快感，你他妈就彻底孤独了。
# 1252    生化危机终章：那个叫爱丽丝的女人决定去死 红皇后告诉爱丽丝：保护伞公司实际上已经发明出了t ...
# 1262    不是在后面的彩蛋里，本来也没彩蛋。。。前面李大爷怀疑丽君的时候不是被绑起来了么，那时候丽君把...
# 1281    从前有一个健康的男孩，爱上了一个患有色盲的女孩。男孩的家人都反对，“色盲可是遗传病啊！”可他...
# ...                                                   ...
# 135602                                   他是她的信仰，而她却成了他的软肋
# 135607  世界经典电影TOP250排行榜1-50这是电视剧下载中心外国电影栏为大家提供的世界经典电影世...
# 135623  小泽玛利亚，拍什么题材都是那副死鱼样，看得我是心里毫无波动，真的是委屈跟她合作的那些男优了，...
# 135651             hodor 演员克里斯蒂安奈恩 冯小刚 元首 阿道夫希特勒----布鲁诺甘茨
# 135671  有一个细节我看大家都没提到，就是吉塔第一次和男孩比赛的时候，选择的不是最强那个吗。然后她一下...
# 135730  冯小刚拍天下无贼的时候真心觉得他是个牛逼的导演。同样作为“列车电影”，天下无贼的质量一点都不...
# 135917  没有。单从影片中也可以得到，女主投靠了别人了。在克里斯人生最苦难的时候，他的妻子选择了离开他...
# 136033  首先，你不可能总是在拍微电影，其次，就算拍微电影，iPhone可以轻松解决，如果你嫌iPho...
# 136094                                 贵妃入浴 禁婆下海 来自微信公众号。
# 136097  1.胖子最近迷上了盗墓小说。而且已经到了走火入魔的地步。语文课上，老师抽背文天祥的过零丁洋点...
# 136101           海上钢琴师中1900本来要下船，结果他只是在台阶上看了看城市的硝烟，转身的时候。
# 136116  没看过原著，单凭电影来看，我的感觉是，安生虽向往家明，但却不会那么容易的和家明在一起，因为还...
# 136130  我记得康震老师讲过一个段子，估计是野史再不就后人杜撰的，但是很有趣 李隆基小时候就帅且机灵，...
# 136155     本杰明，我们命中注定要失去所爱之人，不然我们怎么知道，他们在我们的生命中有多重要？ 返老还童
# 136334  今天中午刚和四年没聚的同学看完 夏洛特烦恼。本来打算看解救吾先生，不过他怕我不喜欢，然后决定...
# 136335  我认为你以为韩庚就是包贝尔婚礼上的韩庚，我想你就错了，抛开包贝尔婚礼这事，我想你们真高估了韩...
# 136367  大护法应该是近两年来最好的一部国产动画电影。我看的是中午一点场，放映厅里坐满了人，当然有家长...
# 136374  似乎大部分人都认为baby比郑爽更符合微微，但我真的从一开始就觉得恰恰相反。我承认baby很...
# 136375  炒作心机婊，星爷面对媒体关于朱茵的逼问只回答过“朱茵不够笨”和“没有开始哪来结束”，至于外界...
# 136424  - 1白脸小丑 White face 典型的白面小丑，脸的底色是白色，眼鼻口则会用红或黑色，...
# 136433  推荐一部最近看过的电影狩猎，整片充斥着冰冷刺骨的北欧风格，平铺直叙的故事里面却充满多幕激烈的...
# 136443                                              新中国发展
# 136444  大家都从摄影方面聊了聊视觉感悟，我想从导演视角谈一谈。视觉上，基本众口一致：有种窥探感。当然...
# 136453  所谓十大禁片，只是因为片中出现了血腥暴力性爱性虐待等不符合主流文化的场面，以及带有灰色意蕴的...
# 136596  是也不是。并且系和系应该也是不同的。本人现在于电影学院读研专业关于摄影。首先，谈几点和本科不...
# 136610  罗根：人间纵有休叔在，世上再无金刚狼 影片质量：45是否推荐：非常推荐严重剧透 听一个故事说...
# 136623   人在气愤的时候甚至会捶打自己的胸部，我现在看到题主这样无中生有的诋毁一部电影，我已经开始捶胸了。
# 136634  3月27更 后面新增的评论我就不回复了，同不同意是你们的自由 假装我是分割线系列 反抄袭的你...
# 136640                       唐老师明显也是整天上B站看你们黑他啊，各种梗倒背如流（逃
# 136658  是的。姜文在让子弹飞之前，拍的片子都不是商业片。这些电影有一部分被禁掉，根本没有在中国电影院...
#
#                                                      desc       qid  star  \
# 5                                                          28163188     3
# 190     题目中的“有可能”，是一种不考虑市场时代国情等现实条件，仅考虑逻辑上的抽象的可能性，比如假设...  26850595   844
# 208            正如前几天大火的问题，又有哪些人物一出场就有必死便当flag或者吾有上将潘凤的赶脚？  42822450    63
# 225                     从小就很喜欢星爷，他的无厘头在我看来无人能及（个人观点，不喜勿喷）  36732589     7
# 237                    幽灵党中感觉bug好多比如打灰机啦还有哪些bug或不符合逻辑之处呢？  37717683    10
# 365                                                        41035200     4
# 412     作为一个普普通通的观众，我有的时候真的分不出来某个演员到底有没有演技。<br>比如大家说某演...  32328952     4
# 484                                                        49263059    19
# 599     为什么三葉本人可以说服她的父亲，泷却无法说服他的岳父？<br><br>回答不限于原电影故事逻...  51266154     3
# 623                                                        21620122    37
# 629     异地恋，我们两人对看电影本身并没有那么大兴趣，只是想一起看些浪漫温馨轻喜剧电影请只是推荐这种...  24309989     3
# 640     指剧情上的。迷雾的结尾算是一个。导演的本意不复杂，就是恶心一下观众而已，原剧本结尾连那些害人...  37060504    28
# 705                                                        31302150     3
# 729     对我个人来说，在电影院看片的感受和家里是不一样的，不只大片，很多文艺片只有在电影院才能看下去...  31076221     7
# 768                             是否能说明大众审美的提高？还是郭敬明没有砸下重金？  51286358     4
# 793     该片讲述了一群拥有超凡智慧与胆量的魔盗四骑士，运用魔术才华，在赢得万众瞩目之后迎来了新的敌人...  46820595    13
# 800                                      有关芝加哥的城市风情或者历史进程  31459473    15
# 874                                                        24507000    17
# 935     那么嗑药，还能戒掉可能吗？是电影的过分夸张不负责任，还是平时的反毒品教育为了让大家远离危害只...  27978662     3
# 993                                                        30776529     3
# 1002    最近看神奇女侠，盖尔加朵的五官简直太完美了。之前在网上有看到一位国外coser出的狼叔特别特...  60826687     7
# 1131                                                       37248069     3
# 1152                                             <img src  24818714     4
# 1171            比如“那个人样子好怪啊。” “我也看到了，他好像条狗啊。”大话西游<br>还有哪些  38123959     7
# 1212                                                镜像问题：  50743390  1048
# 1224    电影盲井盲山的导演李杨转发一篇名为“杨幂们拿这种（国际影后）丢了谁的脸”然后其微博就被粉丝占...  59680820     5
# 1245    举个例子，看到崔永元说：这个时代太二，我不跟了。<br> 我愣了半天：我们紧紧跟随的时代是否...  26830257    29
# 1252    本人是很喜欢生化危机系列电影的，感觉前四部很赞，无论在剧情特效或是格斗场面上都很经典。但是从...  56274661     7
# 1262    在后面等彩蛋，女友说韩国版到后面老爷爷会年轻就一直在等结果结束了都没出现彩蛋，也没有年轻的老...  27745521     3
# 1281                          就是会让人感觉奇葩脑洞有趣搞笑傻呆的推理片段。相关问题  62431401     5
# ...                                                   ...       ...   ...
# 135602                                          电影这个杀手不太冷  22850720     8
# 135607  世界经典电影合集哪里有，我是电影爱好者，很想收藏一些世界经典的电影大片<br>比如：王者归来...  40463568     3
# 135623  年轻演员那个问题基本都是答了国内的，想知道国外（欧美日韩宝莱坞等）有哪些演技不忍直视的演员呢...  49152626   841
# 135651          都说小说人物拍成影视必毁，那么，有没有演员成功的诠释了书里的人物呢？<br>请举例  46918856     3
# 135671  我是老爸和女儿打电话那 最开始由无言 到两个人抱着电话筒哭泣 女儿大声的哭出来 父亲则是默默...  59677690    11
# 135730                                           <a class  61278243     7
# 135917         我很想知道这个答案，当时算是妻子抛弃了丈夫。我一直想知道，最后到底他们在一起了没有，  41479560     3
# 136033                                                     27294453     5
# 136094                                                     27383125    26
# 136097                                                     53932675    32
# 136101                                                     35356821     4
# 136116                                                     50682502    60
# 136130  看过一个视频，岸本说这是他亲自操刀的剧场版，他在漫画完结后基本把所有精力都投入到这部剧场版的...  37534015    31
# 136155     比如“那个人样子好怪啊。” “我也看到了，他好像条狗啊。”大话西游<br>还有哪些类似问题：  38181067    14
# 136334                                                     36013066    10
# 136335                                           <img src  47169047     3
# 136367              看了下预告片，感觉画风清奇，略诡异。今年7月13日会上映，这部动画会火吗？  48238013     3
# 136374  特别是女主。。ab，好看但是演技至于zs。。--<br><br>影版看了一半，剧版在追。抛开...  48477967     3
# 136375                                                     41162916     5
# 136424        小丑左眼右眼下面分别是什么（星星眼泪。位置我不知道）颜色分别是什么？分别有什么寓意嘛？  20294224     3
# 136433  题目又被修改了，还算贴题我就不改了，就是影艺作品的话我主要想问的还是漫画文学电影三块。如果有...  48163412     3
# 136443               本人为央视的大国崛起深深着迷，那么万能的知友们，推荐你们喜欢的纪录片吧。  27325912     3
# 136444  今天，冯小刚导演的新片我不是潘金莲发布了先导预告，全片采用了圆形遮罩，有什么特别的说法吗？或...  41369927    12
# 136453                                                     20614694     7
# 136596                            那里的学生都很厉害吗？<br>普通人能考上吗？  22268622    30
# 136610  请注意：大量答案有剧透，请未观赏者谨慎阅读<br><br>请答题者多考虑未观影者感受！重要人...  55073193    20
# 136623                                                     35761443    11
# 136634  影版三生开始进入宣传期，今天看到团子的造型，脑子里只有俩字：好贵。哈哈，对于服装造型设计这方...  57473530    16
# 136640                                                     36995027    19
# 136658  冯小刚曾说，姜文如果想通了要好好拍商业片，他就是我最大的威胁。<br>姜文在让子弹飞之前的片...  20327454    19
#
#                                                     title topic
# 5                                     为什么美漫里的超级英雄大都性生活混乱？    电影
# 190                    《葫芦娃》有可能拍成《复仇者联盟》一样宏大好看的全年龄向真人电影吗？    电影
# 208                        有哪些人物一出场你就感觉「不妙」「不好的预感」「flag」？    电影
# 225                               周星驰的的无厘头的搞笑风格，会有人传承下去吗？    电影
# 237                                    电影《007幽灵党》中有哪些bug？    电影
# 365                           《疯狂动物城》（Zootopia）中有哪些有趣的细节？    电影
# 412                                   什么是演技？普通观众如何甄别演技优劣？    电影
# 484                                       如何评价电影夏有乔木雅望天堂？    电影
# 599                                 《你的名字。》中三葉最后怎么劝说她爸爸的？    电影
# 623                                           怎样才叫理解一部电影？    电影
# 629                                        有哪些适合恋人一起看的电影？    电影
# 640                                    有哪些著名电影的剧情是故意虐观众的？    电影
# 705                                    影视剧有哪些让你哭得稀里哗啦的情节？    电影
# 729                                       有什么电影重映你会去电影院看？    电影
# 768                                  如何看待《湄公河行动》票房超过《爵迹》？    电影
# 793                                       如何评价电影《惊天魔盗团2》？    电影
# 800                                         有哪些和芝加哥有关的电影？    电影
# 874                                       你们觉得日本最帅的男明星是谁？    电影
# 935                                像《华尔街之狼》的男主角那样吸毒，能活多久？    电影
# 993                             抗日神剧都是什么样的人喜欢看？抱着怎样的心态在看？    电影
# 1002                     东亚人有没有可能通过化妆和后期，cos出超级英雄一样深邃的五官？    电影
# 1131                                      有哪些令人拍案叫绝的推理桥段？    电影
# 1152               罗宾·威廉姆斯(RobinWilliams)曾经演过哪些令你印象深刻的角色？    电影
# 1171                               你看过的电影中最经典的一句电影台词是哪一句？    电影
# 1212                                   2016年你心目中的十大佳片是哪些？    电影
# 1224                            如何看待杨幂粉丝骂《盲山》导演李杨是「野鸡导演」？    电影
# 1245              你从书中电影中歌曲中看过听过哪些句子让你心潮澎湃，突然想停下来审视自己和世界？    电影
# 1252                                     如何评价电影《生化危机6终章》？    电影
# 1262                     《重返20岁》结尾演员表有年轻李大海的人名，为何整个电影未出现？    电影
# 1281                                      有哪些令人拍案笑蠢的推理桥段？    电影
# ...                                                   ...   ...
# 135602            觉得《这个杀手不太冷》里昂对玛婷达不是爱情，假设可以在一起生活，后续会是怎样？    电影
# 135607                       世界经典电影合集哪里有，很想收藏一些世界经典的电影大片？    电影
# 135623                                    国外有哪些演技不忍直视的演员？    电影
# 135651                                     有哪些演员演活了书中的人物？    电影
# 135671                               《摔跤吧！爸爸》中最打动你的场景是哪个？    电影
# 135730                   如何看待冯小刚「中国垃圾电影太多，是因为有垃圾观众捧场」的言论？    电影
# 135917               电影当幸福来敲门听说是根据真人真事改编，那么最后男主还和妻子在一起了么？    电影
# 136033                     手头上有6000元，拍摄微电影，是买台单反好还是买台dv好？    电影
# 136094                                        如何评价范冰冰的演技？    电影
# 136097                                       有哪些关于鬼的有趣故事？    电影
# 136101                                  有哪些电影镜头，让你特别特别感动？    电影
# 136116                 《七月与安生》电影最后安生为何要对家明撒谎说七月没有死，而是去流浪？    电影
# 136130                         如何评价火影最后一部剧场版《BORUTO-博人传》？    电影
# 136155                                        哪句台词你永远忘不了？    电影
# 136334                                     为什么看《夏洛特烦恼》会哭？    电影
# 136335                                     如何评价电影《大话西游3》？    电影
# 136367                                     如何评价动画电影《大护法》？    电影
# 136374                                《微微一笑很倾城》剧版和影版哪个更差？    电影
# 136375                                       周星驰朱茵你们怎么看待？    电影
# 136424                                 小丑这个意象到底有着怎样的代表意义？    电影
# 136433                      是否存在没有死亡情节却能让人感觉到残酷的文学或漫画或电影？    电影
# 136443                                  哪些纪录片让你开阔眼界、增长见识？    电影
# 136444                            如何评价冯小刚导演《我不是潘金莲》的圆形画面？    电影
# 136453  如何评价十大禁片？这十大禁片的感官刺激是否确实其他影片不可比拟的？这十大禁片在电影史上的意义...    电影
# 136596                                   在北京电影学院上学是怎样的体验？    电影
# 136610                          如何评价电影《金刚狼3：殊死一战》（Logan）？    电影
# 136623                         最近上映的电影《小黄人大眼萌》是不是含有政治影射啊？    电影
# 136634                             如何评价电影三生三世十里桃花的服装造型设计？    电影
# 136640                          如何评价唐国强主演的三国题材手游《横扫千军》广告?    电影
# 136658                                  商业电影和非商业电影的区别有哪些？    电影
#
# [3897 rows x 8 columns]

# %%
df_ = df.sample(n=50000)

# %%
sentence = df_.title.tolist()
label = [1 for i in range(df_.shape[0])]
sentence.extend(df_.reply.tolist())
label.extend([0 for i in range(df_.shape[0])])

# %%
df = pd.read_csv('./cut_all.csv')

# %%
sentence = []
sentence.extend(df[df['label'] == 0].sample(10000).review.tolist())
sentence.extend(df[df['label'] == 1].sample(10000).review.tolist())
sentence.extend(df[df['label'] == 2].sample(10000).review.tolist())
sentence.extend(df[df['label'] == 3].sample(10000).review.tolist())

# %%
label = []
label.extend([0 for i in range(10000)])
label.extend([1 for i in range(10000)])
label.extend([2 for i in range(10000)])
label.extend([3 for i in range(10000)])

# %% [markdown]
# # 训练模型

# %%
# X_train, X_test, y_train, y_test = tfidf_processing(sentence, label)

# %%
# %%time
X_train, X_test, y_train, y_test = w2v_processing(sentence, label)
nn, predict = random_forest(X_train, X_test, y_train, y_test)
# joblib.dump(nn, './model/random_forest.pkl', compress=3)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\Zn\AppData\Local\Temp\jieba.cache
# Loading model cost 0.554 seconds.
# Prefix dict has been built succesfully.
# w2v done...
# 训练样本 = 36000
# 测试样本 = 4000
# Wall time: 3min 1s

# %%
predict
# Out:
#       y_predict  y_test
# 0             3       0
# 1             2       3
# 2             0       2
# 3             0       1
# 4             0       2
# 5             2       3
# 6             2       2
# 7             1       0
# 8             1       0
# 9             2       3
# 10            0       3
# 11            0       0
# 12            1       2
# 13            0       3
# 14            1       3
# 15            0       3
# 16            0       0
# 17            3       3
# 18            0       1
# 19            1       1
# 20            1       3
# 21            3       2
# 22            1       2
# 23            3       3
# 24            1       1
# 25            2       3
# 26            3       2
# 27            0       1
# 28            3       2
# 29            0       1
# ...         ...     ...
# 3970          3       2
# 3971          3       3
# 3972          1       0
# 3973          1       0
# 3974          1       3
# 3975          0       1
# 3976          0       0
# 3977          2       3
# 3978          2       3
# 3979          2       3
# 3980          1       3
# 3981          0       1
# 3982          0       2
# 3983          0       0
# 3984          1       1
# 3985          2       1
# 3986          3       0
# 3987          3       2
# 3988          3       3
# 3989          0       1
# 3990          3       2
# 3991          0       3
# 3992          2       1
# 3993          0       1
# 3994          3       3
# 3995          0       0
# 3996          0       2
# 3997          0       1
# 3998          0       0
# 3999          1       1
#
# [4000 rows x 2 columns]

# %%
tfidf_model = joblib.load('./model/tfidf_model.pkl')
random_forest_model = joblib.load('./model/random_forest.pkl')

# %% [markdown]
# # 测试模型

# %%
tf = [np.array(get_vec('以此纪念九一八！宜黄县政府网站。', cut_all))]
nn.predict_proba(tf), nn.predict(tf)
# Out:
# (array([[0.24724805, 0.2681345 , 0.24890268, 0.23571477]]), array([1]))

# %%
random_forest_model.predict_proba(np.array([sentence_vector('a ', model)]))
# Out:
# D:\Tools\Anaconda\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   app.launch_new_instance()
# array([[0.375, 0.625]])

# %%
model.wv.vocab
# Out:
# {'招行': <gensim.models.keyedvectors.Vocab at 0x1d1afba4940>,
#  '积分换': <gensim.models.keyedvectors.Vocab at 0x1d1afba4ac8>,
#  '国航': <gensim.models.keyedvectors.Vocab at 0x1d1afba4b38>,
#  '里程': <gensim.models.keyedvectors.Vocab at 0x1d1afba4ba8>,
#  '多久': <gensim.models.keyedvectors.Vocab at 0x1d1afba4c18>,
#  '到': <gensim.models.keyedvectors.Vocab at 0x1d1afba4c50>,
#  '不是': <gensim.models.keyedvectors.Vocab at 0x1d1afba4c88>,
#  '有': <gensim.models.keyedvectors.Vocab at 0x1d1afba4d30>,
#  '一年': <gensim.models.keyedvectors.Vocab at 0x1d1afba4e80>,
#  '的': <gensim.models.keyedvectors.Vocab at 0x1d1afba4f98>,
#  '分期': <gensim.models.keyedvectors.Vocab at 0x1d1afbbc160>,
#  '吗': <gensim.models.keyedvectors.Vocab at 0x1d1afbbc278>,
#  '？': <gensim.models.keyedvectors.Vocab at 0x1d1afbbc390>,
#  '没有': <gensim.models.keyedvectors.Vocab at 0x1d1afbbc4a8>,
#  '利息': <gensim.models.keyedvectors.Vocab at 0x1d1afbbc5c0>,
#  '年底': <gensim.models.keyedvectors.Vocab at 0x1d1afbbc6d8>,
#  '投资': <gensim.models.keyedvectors.Vocab at 0x1d1afbbc7f0>,
#  '理财': <gensim.models.keyedvectors.Vocab at 0x1d1afbbc908>,
#  '骗局': <gensim.models.keyedvectors.Vocab at 0x1d1afbbca20>,
#  '多': <gensim.models.keyedvectors.Vocab at 0x1d1afbbcb70>,
#  '如何': <gensim.models.keyedvectors.Vocab at 0x1d1afbbcc88>,
#  '才能': <gensim.models.keyedvectors.Vocab at 0x1d1afbbcda0>,
#  '安心': <gensim.models.keyedvectors.Vocab at 0x1d1afbbceb8>,
#  '您好': <gensim.models.keyedvectors.Vocab at 0x1d1afbc5048>,
#  '！': <gensim.models.keyedvectors.Vocab at 0x1d1afbc5160>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x1d1afbc5278>,
#  '、': <gensim.models.keyedvectors.Vocab at 0x1d1afbc5390>,
#  '等额': <gensim.models.keyedvectors.Vocab at 0x1d1afbc54e0>,
#  '本息': <gensim.models.keyedvectors.Vocab at 0x1d1afbc55f8>,
#  '还款法': <gensim.models.keyedvectors.Vocab at 0x1d1afbc5710>,
#  '：': <gensim.models.keyedvectors.Vocab at 0x1d1afbc5828>,
#  '每期': <gensim.models.keyedvectors.Vocab at 0x1d1afbc5978>,
#  '还款额': <gensim.models.keyedvectors.Vocab at 0x1d1afbc5a90>,
#  '=': <gensim.models.keyedvectors.Vocab at 0x1d1afbc5ba8>,
#  '借款': <gensim.models.keyedvectors.Vocab at 0x1d1afbc5cc0>,
#  '本金': <gensim.models.keyedvectors.Vocab at 0x1d1afbc5dd8>,
#  '×': <gensim.models.keyedvectors.Vocab at 0x1d1afbc5ef0>,
#  '期': <gensim.models.keyedvectors.Vocab at 0x1d1afbcb048>,
#  '利率': <gensim.models.keyedvectors.Vocab at 0x1d1afbcb160>,
#  '（': <gensim.models.keyedvectors.Vocab at 0x1d1afbcb278>,
#  '+': <gensim.models.keyedvectors.Vocab at 0x1d1afbcb390>,
#  '）': <gensim.models.keyedvectors.Vocab at 0x1d1afbcb4a8>,
#  '^': <gensim.models.keyedvectors.Vocab at 0x1d1afbcb5c0>,
#  '期数': <gensim.models.keyedvectors.Vocab at 0x1d1afbcb6d8>,
#  '/': <gensim.models.keyedvectors.Vocab at 0x1d1afbcb7f0>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x1d1afbcb908>,
#  '；': <gensim.models.keyedvectors.Vocab at 0x1d1afbcba20>,
#  '表示': <gensim.models.keyedvectors.Vocab at 0x1d1afbcbb38>,
#  '幂': <gensim.models.keyedvectors.Vocab at 0x1d1afbcbc50>,
#  '，': <gensim.models.keyedvectors.Vocab at 0x1d1afbcbda0>,
#  '如': <gensim.models.keyedvectors.Vocab at 0x1d1afbcbf28>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x1d1b0990080>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x1d1b0990198>,
#  '次方': <gensim.models.keyedvectors.Vocab at 0x1d1b09902b0>,
#  '通常': <gensim.models.keyedvectors.Vocab at 0x1d1b0990400>,
#  '以': <gensim.models.keyedvectors.Vocab at 0x1d1b0990518>,
#  '月': <gensim.models.keyedvectors.Vocab at 0x1d1b0990630>,
#  '为': <gensim.models.keyedvectors.Vocab at 0x1d1b0990748>,
#  '单位': <gensim.models.keyedvectors.Vocab at 0x1d1b0990860>,
#  '和': <gensim.models.keyedvectors.Vocab at 0x1d1b0990978>,
#  '注意': <gensim.models.keyedvectors.Vocab at 0x1d1b0990a90>,
#  '换算': <gensim.models.keyedvectors.Vocab at 0x1d1b0990ba8>,
#  '。': <gensim.models.keyedvectors.Vocab at 0x1d1b0990cc0>,
#  '等': <gensim.models.keyedvectors.Vocab at 0x1d1b0990e48>,
#  '本': <gensim.models.keyedvectors.Vocab at 0x1d1b0990f60>,
#  '递减': <gensim.models.keyedvectors.Vocab at 0x1d1b09950b8>,
#  '累计': <gensim.models.keyedvectors.Vocab at 0x1d1b09951d0>,
#  '已': <gensim.models.keyedvectors.Vocab at 0x1d1b09952e8>,
#  '还': <gensim.models.keyedvectors.Vocab at 0x1d1b0995400>,
#  '金额': <gensim.models.keyedvectors.Vocab at 0x1d1b0995518>,
#  '望': <gensim.models.keyedvectors.Vocab at 0x1d1b0995630>,
#  '采纳': <gensim.models.keyedvectors.Vocab at 0x1d1b0995748>,
#  '谢谢': <gensim.models.keyedvectors.Vocab at 0x1d1b0995860>,
#  '车位': <gensim.models.keyedvectors.Vocab at 0x1d1b0995978>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x1d1b0995a90>,
#  '家': <gensim.models.keyedvectors.Vocab at 0x1d1b0995ba8>,
#  '可以': <gensim.models.keyedvectors.Vocab at 0x1d1b0995cc0>,
#  '抵押': <gensim.models.keyedvectors.Vocab at 0x1d1b0995e10>,
#  '以后': <gensim.models.keyedvectors.Vocab at 0x1d1b0995f28>,
#  '不': <gensim.models.keyedvectors.Vocab at 0x1d1b099d080>,
#  '影响': <gensim.models.keyedvectors.Vocab at 0x1d1b099d198>,
#  '使用': <gensim.models.keyedvectors.Vocab at 0x1d1b099d2b0>,
#  '但是': <gensim.models.keyedvectors.Vocab at 0x1d1b099d3c8>,
#  '无法': <gensim.models.keyedvectors.Vocab at 0x1d1b099d4e0>,
#  '钱': <gensim.models.keyedvectors.Vocab at 0x1d1b099d5f8>,
#  '就': <gensim.models.keyedvectors.Vocab at 0x1d1b099d710>,
#  '几年': <gensim.models.keyedvectors.Vocab at 0x1d1b099d828>,
#  '不能': <gensim.models.keyedvectors.Vocab at 0x1d1b099d940>,
#  '用': <gensim.models.keyedvectors.Vocab at 0x1d1b099da58>,
#  '了': <gensim.models.keyedvectors.Vocab at 0x1d1b099db70>,
#  '通过': <gensim.models.keyedvectors.Vocab at 0x1d1b099dcc0>,
#  '手机': <gensim.models.keyedvectors.Vocab at 0x1d1b099ddd8>,
#  '银行': <gensim.models.keyedvectors.Vocab at 0x1d1b099def0>,
#  '或者': <gensim.models.keyedvectors.Vocab at 0x1d1b09a1080>,
#  '电话': <gensim.models.keyedvectors.Vocab at 0x1d1b09a1198>,
#  '都': <gensim.models.keyedvectors.Vocab at 0x1d1b09a12b0>,
#  '七': <gensim.models.keyedvectors.Vocab at 0x1d1b09a13c8>,
#  '*': <gensim.models.keyedvectors.Vocab at 0x1d1b09a1518>,
#  '河': <gensim.models.keyedvectors.Vocab at 0x1d1b09a1668>,
#  '工': <gensim.models.keyedvectors.Vocab at 0x1d1b09a1780>,
#  '招': <gensim.models.keyedvectors.Vocab at 0x1d1b09a18d0>,
#  '银': <gensim.models.keyedvectors.Vocab at 0x1d1b09a19e8>,
#  '激活': <gensim.models.keyedvectors.Vocab at 0x1d1b09a1b00>,
#  '后': <gensim.models.keyedvectors.Vocab at 0x1d1b09a1c18>,
#  '人工': <gensim.models.keyedvectors.Vocab at 0x1d1b09a1d30>,
#  '审核': <gensim.models.keyedvectors.Vocab at 0x1d1b09a1e48>,
#  '需要': <gensim.models.keyedvectors.Vocab at 0x1d1b09a1f60>,
#  '多长时间': <gensim.models.keyedvectors.Vocab at 0x1d1b09a70b8>,
#  '这个': <gensim.models.keyedvectors.Vocab at 0x1d1b09a71d0>,
#  '您': <gensim.models.keyedvectors.Vocab at 0x1d1b09a72e8>,
#  '问': <gensim.models.keyedvectors.Vocab at 0x1d1b09a7438>,
#  '公司财务': <gensim.models.keyedvectors.Vocab at 0x1d1b09a7550>,
#  '其他': <gensim.models.keyedvectors.Vocab at 0x1d1b09a76a0>,
#  '同事': <gensim.models.keyedvectors.Vocab at 0x1d1b09a77b8>,
#  '看': <gensim.models.keyedvectors.Vocab at 0x1d1b09a7908>,
#  '是否': <gensim.models.keyedvectors.Vocab at 0x1d1b09a7a20>,
#  '奖金': <gensim.models.keyedvectors.Vocab at 0x1d1b09a7b38>,
#  '工资': <gensim.models.keyedvectors.Vocab at 0x1d1b09a7c88>,
#  '分开': <gensim.models.keyedvectors.Vocab at 0x1d1b09a7da0>,
#  '发放': <gensim.models.keyedvectors.Vocab at 0x1d1b09a7ef0>,
#  '哦': <gensim.models.keyedvectors.Vocab at 0x1d1b09ab048>,
#  '这样': <gensim.models.keyedvectors.Vocab at 0x1d1b09ab160>,
#  '是': <gensim.models.keyedvectors.Vocab at 0x1d1b09ab278>,
#  '合法': <gensim.models.keyedvectors.Vocab at 0x1d1b09ab3c8>,
#  '也': <gensim.models.keyedvectors.Vocab at 0x1d1b09ab4e0>,
#  '合理': <gensim.models.keyedvectors.Vocab at 0x1d1b09ab5f8>,
#  '招商': <gensim.models.keyedvectors.Vocab at 0x1d1b09ab710>,
#  '信用卡': <gensim.models.keyedvectors.Vocab at 0x1d1b09ab828>,
#  '半年': <gensim.models.keyedvectors.Vocab at 0x1d1b09ab978>,
#  '没': <gensim.models.keyedvectors.Vocab at 0x1d1b09aba90>,
#  '怎么办': <gensim.models.keyedvectors.Vocab at 0x1d1b09abba8>,
#  '办': <gensim.models.keyedvectors.Vocab at 0x1d1b09abcc0>,
#  '银行卡': <gensim.models.keyedvectors.Vocab at 0x1d1b09abdd8>,
#  '直接': <gensim.models.keyedvectors.Vocab at 0x1d1b09abef0>,
#  '拿': <gensim.models.keyedvectors.Vocab at 0x1d1b09b2048>,
#  '着': <gensim.models.keyedvectors.Vocab at 0x1d1b09b2160>,
#  '本人': <gensim.models.keyedvectors.Vocab at 0x1d1b09b2278>,
#  '身份证': <gensim.models.keyedvectors.Vocab at 0x1d1b09b2390>,
#  '去': <gensim.models.keyedvectors.Vocab at 0x1d1b09b24a8>,
#  '办理': <gensim.models.keyedvectors.Vocab at 0x1d1b09b25c0>,
#  '1000': <gensim.models.keyedvectors.Vocab at 0x1d1b09b2710>,
#  '元': <gensim.models.keyedvectors.Vocab at 0x1d1b09b27b8>,
#  '真品': <gensim.models.keyedvectors.Vocab at 0x1d1b09b28d0>,
#  '品种': <gensim.models.keyedvectors.Vocab at 0x1d1b09b2a20>,
#  '收藏': <gensim.models.keyedvectors.Vocab at 0x1d1b09b2b38>,
#  '价值': <gensim.models.keyedvectors.Vocab at 0x1d1b09b2c88>,
#  '比较': <gensim.models.keyedvectors.Vocab at 0x1d1b09b2da0>,
#  '高': <gensim.models.keyedvectors.Vocab at 0x1d1b09b2eb8>,
#  '一定': <gensim.models.keyedvectors.Vocab at 0x1d1b09b2fd0>,
#  '市场潜力': <gensim.models.keyedvectors.Vocab at 0x1d1b09b70b8>,
#  '若': <gensim.models.keyedvectors.Vocab at 0x1d1b09b7208>,
#  '提高': <gensim.models.keyedvectors.Vocab at 0x1d1b09b7320>,
#  '我行': <gensim.models.keyedvectors.Vocab at 0x1d1b09b7438>,
#  '固定': <gensim.models.keyedvectors.Vocab at 0x1d1b09b7550>,
#  '额度': <gensim.models.keyedvectors.Vocab at 0x1d1b09b7668>,
#  '一般': <gensim.models.keyedvectors.Vocab at 0x1d1b09b7780>,
#  '天': <gensim.models.keyedvectors.Vocab at 0x1d1b09b7898>,
#  '左右': <gensim.models.keyedvectors.Vocab at 0x1d1b09b79b0>,
#  '提升': <gensim.models.keyedvectors.Vocab at 0x1d1b09b7ac8>,
#  '成功': <gensim.models.keyedvectors.Vocab at 0x1d1b09b7be0>,
#  '会': <gensim.models.keyedvectors.Vocab at 0x1d1b09b7cf8>,
#  '发送': <gensim.models.keyedvectors.Vocab at 0x1d1b09b7e10>,
#  '短信': <gensim.models.keyedvectors.Vocab at 0x1d1b09b7f28>,
#  '提醒': <gensim.models.keyedvectors.Vocab at 0x1d1b09bc080>,
#  '水滴': <gensim.models.keyedvectors.Vocab at 0x1d1b09bc198>,
#  '贷有': <gensim.models.keyedvectors.Vocab at 0x1d1b09bc2e8>,
#  '放款': <gensim.models.keyedvectors.Vocab at 0x1d1b09bc438>,
#  '携带': <gensim.models.keyedvectors.Vocab at 0x1d1b09bc550>,
#  '卡': <gensim.models.keyedvectors.Vocab at 0x1d1b09bc668>,
#  '或': <gensim.models.keyedvectors.Vocab at 0x1d1b09bc780>,
#  '存折': <gensim.models.keyedvectors.Vocab at 0x1d1b09bc898>,
#  '所属': <gensim.models.keyedvectors.Vocab at 0x1d1b09bc9b0>,
#  '营业网点': <gensim.models.keyedvectors.Vocab at 0x1d1b09bcac8>,
#  '非现金': <gensim.models.keyedvectors.Vocab at 0x1d1b09bcbe0>,
#  '业务': <gensim.models.keyedvectors.Vocab at 0x1d1b09bcd30>,
#  '窗口': <gensim.models.keyedvectors.Vocab at 0x1d1b09bce48>,
#  '工作人员': <gensim.models.keyedvectors.Vocab at 0x1d1b09bcf60>,
#  '打印': <gensim.models.keyedvectors.Vocab at 0x1d1b09c30b8>,
#  '盖': <gensim.models.keyedvectors.Vocab at 0x1d1b09c31d0>,
#  '银行业务': <gensim.models.keyedvectors.Vocab at 0x1d1b09c3320>,
#  '红章': <gensim.models.keyedvectors.Vocab at 0x1d1b09c3438>,
#  '权威性': <gensim.models.keyedvectors.Vocab at 0x1d1b09c3588>,
#  '相对': <gensim.models.keyedvectors.Vocab at 0x1d1b09c36d8>,
#  '较': <gensim.models.keyedvectors.Vocab at 0x1d1b09c37f0>,
#  '主要': <gensim.models.keyedvectors.Vocab at 0x1d1b09c3908>,
#  '作': <gensim.models.keyedvectors.Vocab at 0x1d1b09c3a20>,
#  '银行贷款': <gensim.models.keyedvectors.Vocab at 0x1d1b09c3b38>,
#  '财力': <gensim.models.keyedvectors.Vocab at 0x1d1b09c3c50>,
#  '证明': <gensim.models.keyedvectors.Vocab at 0x1d1b09c3d68>,
#  '理财产品': <gensim.models.keyedvectors.Vocab at 0x1d1b09c3e80>,
#  '千千万': <gensim.models.keyedvectors.Vocab at 0x1d1b09c3f98>,
#  '金': <gensim.models.keyedvectors.Vocab at 0x1d1b09c8128>,
#  '眼睛': <gensim.models.keyedvectors.Vocab at 0x1d1b09c8240>,
#  '看出': <gensim.models.keyedvectors.Vocab at 0x1d1b09c8390>,
#  '谁': <gensim.models.keyedvectors.Vocab at 0x1d1b09c84e0>,
#  '最强': <gensim.models.keyedvectors.Vocab at 0x1d1b09c85f8>,
#  '什么': <gensim.models.keyedvectors.Vocab at 0x1d1b09c8748>,
#  '合规': <gensim.models.keyedvectors.Vocab at 0x1d1b09c8860>,
#  '小额贷款': <gensim.models.keyedvectors.Vocab at 0x1d1b09c89b0>,
#  '平台': <gensim.models.keyedvectors.Vocab at 0x1d1b09c8ac8>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x1d1b09c8be0>,
#  '哪里': <gensim.models.keyedvectors.Vocab at 0x1d1b09c8cf8>,
#  '接到': <gensim.models.keyedvectors.Vocab at 0x1d1b09c8e10>,
#  '你': <gensim.models.keyedvectors.Vocab at 0x1d1b09c8f28>,
#  '人脉': <gensim.models.keyedvectors.Vocab at 0x1d1b09d0080>,
#  '运气': <gensim.models.keyedvectors.Vocab at 0x1d1b09d01d0>,
#  '有效期': <gensim.models.keyedvectors.Vocab at 0x1d1b09d0320>,
#  '市': <gensim.models.keyedvectors.Vocab at 0x1d1b09d0438>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x1d1b09d0550>,
#  '年': <gensim.models.keyedvectors.Vocab at 0x1d1b09d0668>,
#  '显示': <gensim.models.keyedvectors.Vocab at 0x1d1b09d0780>,
#  '在': <gensim.models.keyedvectors.Vocab at 0x1d1b09d0898>,
#  '16': <gensim.models.keyedvectors.Vocab at 0x1d1b09d0a20>,
#  '位': <gensim.models.keyedvectors.Vocab at 0x1d1b09d0b38>,
#  '卡号': <gensim.models.keyedvectors.Vocab at 0x1d1b09d0c50>,
#  '下方': <gensim.models.keyedvectors.Vocab at 0x1d1b09d0d68>,
#  '举例': <gensim.models.keyedvectors.Vocab at 0x1d1b09d0e80>,
#  '数字': <gensim.models.keyedvectors.Vocab at 0x1d1b09d0fd0>,
#  '02': <gensim.models.keyedvectors.Vocab at 0x1d1b09d6160>,
#  '21': <gensim.models.keyedvectors.Vocab at 0x1d1b09d62b0>,
#  '就是指': <gensim.models.keyedvectors.Vocab at 0x1d1b09d63c8>,
#  '2016': <gensim.models.keyedvectors.Vocab at 0x1d1b09d6550>,
#  '发卡': <gensim.models.keyedvectors.Vocab at 0x1d1b09d6668>,
#  '2021': <gensim.models.keyedvectors.Vocab at 0x1d1b09d67b8>,
#  '月底': <gensim.models.keyedvectors.Vocab at 0x1d1b09d6908>,
#  '到期': <gensim.models.keyedvectors.Vocab at 0x1d1b09d6a20>,
#  '只': <gensim.models.keyedvectors.Vocab at 0x1d1b09d6b38>,
#  '写': <gensim.models.keyedvectors.Vocab at 0x1d1b09d6c50>,
#  '买': <gensim.models.keyedvectors.Vocab at 0x1d1b09d6d68>,
#  '安全': <gensim.models.keyedvectors.Vocab at 0x1d1b09d6e80>,
#  '申请': <gensim.models.keyedvectors.Vocab at 0x1d1b09d6f98>,
#  '情况': <gensim.models.keyedvectors.Vocab at 0x1d1b09db128>,
#  '下普卡': <gensim.models.keyedvectors.Vocab at 0x1d1b09db240>,
#  '范围': <gensim.models.keyedvectors.Vocab at 0x1d1b09db358>,
#  '￥': <gensim.models.keyedvectors.Vocab at 0x1d1b09db400>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x1d1b09db518>,
#  '000': <gensim.models.keyedvectors.Vocab at 0x1d1b09db668>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x1d1b09db7b8>,
#  '金卡': <gensim.models.keyedvectors.Vocab at 0x1d1b09db8d0>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x1d1b09dba20>,
#  '具体': <gensim.models.keyedvectors.Vocab at 0x1d1b09dbb38>,
#  '结果': <gensim.models.keyedvectors.Vocab at 0x1d1b09dbc50>,
#  '为准': <gensim.models.keyedvectors.Vocab at 0x1d1b09dbd68>,
#  '排除': <gensim.models.keyedvectors.Vocab at 0x1d1b09dbe80>,
#  '普卡有': <gensim.models.keyedvectors.Vocab at 0x1d1b09dbf98>,
#  '网上': <gensim.models.keyedvectors.Vocab at 0x1d1b09e0128>,
#  '预约': <gensim.models.keyedvectors.Vocab at 0x1d1b09e0240>,
#  '登记': <gensim.models.keyedvectors.Vocab at 0x1d1b09e0358>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x1d1b09e0470>,
#  '个': <gensim.models.keyedvectors.Vocab at 0x1d1b09e0588>,
#  '工作日': <gensim.models.keyedvectors.Vocab at 0x1d1b09e06a0>,
#  '初审': <gensim.models.keyedvectors.Vocab at 0x1d1b09e07b8>,
#  '时间': <gensim.models.keyedvectors.Vocab at 0x1d1b09e08d0>,
#  '联络': <gensim.models.keyedvectors.Vocab at 0x1d1b09e09e8>,
#  '上门': <gensim.models.keyedvectors.Vocab at 0x1d1b09e0b38>,
#  '收取': <gensim.models.keyedvectors.Vocab at 0x1d1b09e0c50>,
#  '书面资料': <gensim.models.keyedvectors.Vocab at 0x1d1b09e0d68>,
#  '通知': <gensim.models.keyedvectors.Vocab at 0x1d1b09e0eb8>,
#  '填单': <gensim.models.keyedvectors.Vocab at 0x1d1b09e0fd0>,
#  '受理': <gensim.models.keyedvectors.Vocab at 0x1d1b09e6160>,
#  '请': <gensim.models.keyedvectors.Vocab at 0x1d1b09e6278>,
#  '日内': <gensim.models.keyedvectors.Vocab at 0x1d1b09e6390>,
#  '居民身份证': <gensim.models.keyedvectors.Vocab at 0x1d1b09e64e0>,
#  '柜台': <gensim.models.keyedvectors.Vocab at 0x1d1b09e65f8>,
#  '办卡': <gensim.models.keyedvectors.Vocab at 0x1d1b09e6710>,
#  '帮': <gensim.models.keyedvectors.Vocab at 0x1d1b09e6828>,
#  '安排': <gensim.models.keyedvectors.Vocab at 0x1d1b09e6940>,
#  '制卡': <gensim.models.keyedvectors.Vocab at 0x1d1b09e6a58>,
#  '制卡后': <gensim.models.keyedvectors.Vocab at 0x1d1b09e6b70>,
#  '邮寄': <gensim.models.keyedvectors.Vocab at 0x1d1b09e6cc0>,
#  '给': <gensim.models.keyedvectors.Vocab at 0x1d1b09e6dd8>,
#  '哪个': <gensim.models.keyedvectors.Vocab at 0x1d1b09e6ef0>,
#  '城市': <gensim.models.keyedvectors.Vocab at 0x1d1b09ed048>,
#  'OK': <gensim.models.keyedvectors.Vocab at 0x1d1b09ed198>,
#  '不算': <gensim.models.keyedvectors.Vocab at 0x1d1b09ed2e8>,
#  '很难': <gensim.models.keyedvectors.Vocab at 0x1d1b09ed400>,
#  '啊': <gensim.models.keyedvectors.Vocab at 0x1d1b09ed518>,
#  '沈': <gensim.models.keyedvectors.Vocab at 0x1d1b09ed630>,
#  '周日': <gensim.models.keyedvectors.Vocab at 0x1d1b09ed748>,
#  '存单': <gensim.models.keyedvectors.Vocab at 0x1d1b09ed860>,
#  '取钱': <gensim.models.keyedvectors.Vocab at 0x1d1b09ed978>,
#  '招商银行': <gensim.models.keyedvectors.Vocab at 0x1d1b09eda90>,
#  '除非': <gensim.models.keyedvectors.Vocab at 0x1d1b09edba8>,
#  '国企': <gensim.models.keyedvectors.Vocab at 0x1d1b09edcc0>,
#  '上班': <gensim.models.keyedvectors.Vocab at 0x1d1b09ede10>,
#  '大学生': <gensim.models.keyedvectors.Vocab at 0x1d1b09edf28>,
#  '才': <gensim.models.keyedvectors.Vocab at 0x1d1b09f2080>,
#  '好': <gensim.models.keyedvectors.Vocab at 0x1d1b09f2198>,
#  '下款': <gensim.models.keyedvectors.Vocab at 0x1d1b09f22b0>,
#  '请问': <gensim.models.keyedvectors.Vocab at 0x1d1b09f23c8>,
#  '开张': <gensim.models.keyedvectors.Vocab at 0x1d1b09f24e0>,
#  '通': <gensim.models.keyedvectors.Vocab at 0x1d1b09f2630>,
#  'v': <gensim.models.keyedvectors.Vocab at 0x1d1b09f2748>,
#  's': <gensim.models.keyedvectors.Vocab at 0x1d1b09f2898>,
#  '其它': <gensim.models.keyedvectors.Vocab at 0x1d1b09f29b0>,
#  '证件': <gensim.models.keyedvectors.Vocab at 0x1d1b09f2ac8>,
#  '开卡': <gensim.models.keyedvectors.Vocab at 0x1d1b09f2be0>,
#  '多少': <gensim.models.keyedvectors.Vocab at 0x1d1b09f2cf8>,
#  '不同': <gensim.models.keyedvectors.Vocab at 0x1d1b09f2e10>,
#  '逾期': <gensim.models.keyedvectors.Vocab at 0x1d1b09f2f28>,
#  '提额': <gensim.models.keyedvectors.Vocab at 0x1d1b09f8080>,
#  '必然联系': <gensim.models.keyedvectors.Vocab at 0x1d1b09f8198>,
#  '代表': <gensim.models.keyedvectors.Vocab at 0x1d1b09f82e8>,
#  '提': <gensim.models.keyedvectors.Vocab at 0x1d1b09f8400>,
#  '打电话': <gensim.models.keyedvectors.Vocab at 0x1d1b09f8518>,
#  '客服': <gensim.models.keyedvectors.Vocab at 0x1d1b09f8630>,
#  '而且': <gensim.models.keyedvectors.Vocab at 0x1d1b09f8748>,
#  '要': <gensim.models.keyedvectors.Vocab at 0x1d1b09f8860>,
#  '间隔': <gensim.models.keyedvectors.Vocab at 0x1d1b09f8978>,
#  '三个': <gensim.models.keyedvectors.Vocab at 0x1d1b09f8ac8>,
#  '六个月': <gensim.models.keyedvectors.Vocab at 0x1d1b09f8be0>,
#  '主动': <gensim.models.keyedvectors.Vocab at 0x1d1b09f8cf8>,
#  '大': <gensim.models.keyedvectors.Vocab at 0x1d1b09f8e10>,
#  '目前': <gensim.models.keyedvectors.Vocab at 0x1d1b09f8f28>,
#  '网点': <gensim.models.keyedvectors.Vocab at 0x1d1b0a00080>,
#  '关于': <gensim.models.keyedvectors.Vocab at 0x1d1b0a00198>,
#  '自助': <gensim.models.keyedvectors.Vocab at 0x1d1b0a002b0>,
#  '设备': <gensim.models.keyedvectors.Vocab at 0x1d1b0a003c8>,
#  '分布': <gensim.models.keyedvectors.Vocab at 0x1d1b0a004e0>,
#  '及': <gensim.models.keyedvectors.Vocab at 0x1d1b0a005f8>,
#  '营业时间': <gensim.models.keyedvectors.Vocab at 0x1d1b0a00710>,
#  '交通': <gensim.models.keyedvectors.Vocab at 0x1d1b0a00828>,
#  '参考': <gensim.models.keyedvectors.Vocab at 0x1d1b0a00940>,
#  'http': <gensim.models.keyedvectors.Vocab at 0x1d1b0a00a90>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x1d1b0a00ba8>,
#  'map': <gensim.models.keyedvectors.Vocab at 0x1d1b0a00cf8>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x1d1b0a00e10>,
#  'cm': <gensim.models.keyedvectors.Vocab at 0x1d1b0a00f60>,
#  '####': <gensim.models.keyedvectors.Vocab at 0x1d1b0a050f0>,
#  'na': <gensim.models.keyedvectors.Vocab at 0x1d1b0a05240>,
#  'com': <gensim.models.keyedvectors.Vocab at 0x1d1b0a05390>,
#  '查询': <gensim.models.keyedvectors.Vocab at 0x1d1b0a054a8>,
#  '烦请': <gensim.models.keyedvectors.Vocab at 0x1d1b0a055c0>,
#  '提供': <gensim.models.keyedvectors.Vocab at 0x1d1b0a056d8>,
#  '我们': <gensim.models.keyedvectors.Vocab at 0x1d1b0a057f0>,
#  '进一步': <gensim.models.keyedvectors.Vocab at 0x1d1b0a05908>,
#  '建议您': <gensim.models.keyedvectors.Vocab at 0x1d1b0a05a20>,
#  '之前': <gensim.models.keyedvectors.Vocab at 0x1d1b0a05b38>,
#  '先': <gensim.models.keyedvectors.Vocab at 0x1d1b0a05c50>,
#  '联系': <gensim.models.keyedvectors.Vocab at 0x1d1b0a05d68>,
#  '支行': <gensim.models.keyedvectors.Vocab at 0x1d1b0a05e80>,
#  '确认': <gensim.models.keyedvectors.Vocab at 0x1d1b0a05f98>,
#  '以免': <gensim.models.keyedvectors.Vocab at 0x1d1b0a0a0f0>,
#  '临时': <gensim.models.keyedvectors.Vocab at 0x1d1b0a0a208>,
#  '停业': <gensim.models.keyedvectors.Vocab at 0x1d1b0a0a320>,
#  '造成': <gensim.models.keyedvectors.Vocab at 0x1d1b0a0a470>,
#  '不便': <gensim.models.keyedvectors.Vocab at 0x1d1b0a0a588>,
#  '我': <gensim.models.keyedvectors.Vocab at 0x1d1b0a0a6a0>,
#  '现在': <gensim.models.keyedvectors.Vocab at 0x1d1b0a0a7b8>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x1d1b0a0a908>,
#  '岁': <gensim.models.keyedvectors.Vocab at 0x1d1b0a0aa20>,
#  '急需': <gensim.models.keyedvectors.Vocab at 0x1d1b0a0ab38>,
#  '一万块': <gensim.models.keyedvectors.Vocab at 0x1d1b0a0ac50>,
#  '我该': <gensim.models.keyedvectors.Vocab at 0x1d1b0a0ad68>,
#  '未满': <gensim.models.keyedvectors.Vocab at 0x1d1b0a0ae80>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x1d1b0a0afd0>,
#  '周岁': <gensim.models.keyedvectors.Vocab at 0x1d1b0a11128>,
#  '不了': <gensim.models.keyedvectors.Vocab at 0x1d1b0a11240>,
#  '贷款': <gensim.models.keyedvectors.Vocab at 0x1d1b0a11358>,
#  '完全': <gensim.models.keyedvectors.Vocab at 0x1d1b0a114a8>,
#  '民事行为': <gensim.models.keyedvectors.Vocab at 0x1d1b0a115c0>,
#  '能力': <gensim.models.keyedvectors.Vocab at 0x1d1b0a116d8>,
#  '指': <gensim.models.keyedvectors.Vocab at 0x1d1b0a117f0>,
#  '记录': <gensim.models.keyedvectors.Vocab at 0x1d1b0a11908>,
#  '能': <gensim.models.keyedvectors.Vocab at 0x1d1b0a11a20>,
#  '买房': <gensim.models.keyedvectors.Vocab at 0x1d1b0a11ac8>,
#  '所在城市': <gensim.models.keyedvectors.Vocab at 0x1d1b0a11be0>,
#  '可': <gensim.models.keyedvectors.Vocab at 0x1d1b0a11cf8>,
#  '尝试': <gensim.models.keyedvectors.Vocab at 0x1d1b0a11e10>,
#  '各': <gensim.models.keyedvectors.Vocab at 0x1d1b0a11f28>,
#  '项目': <gensim.models.keyedvectors.Vocab at 0x1d1b0a15080>,
#  '所': <gensim.models.keyedvectors.Vocab at 0x1d1b0a15198>,
#  '需': <gensim.models.keyedvectors.Vocab at 0x1d1b0a152b0>,
#  '条件': <gensim.models.keyedvectors.Vocab at 0x1d1b0a153c8>,
#  '申请材料': <gensim.models.keyedvectors.Vocab at 0x1d1b0a154e0>,
#  '有所不同': <gensim.models.keyedvectors.Vocab at 0x1d1b0a155f8>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x1d1b0a15710>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x1d1b0a15860>,
#  '00': <gensim.models.keyedvectors.Vocab at 0x1d1b0a159b0>,
#  '致电': <gensim.models.keyedvectors.Vocab at 0x1d1b0a15ac8>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x1d1b0a15be0>,
#  '咨询': <gensim.models.keyedvectors.Vocab at 0x1d1b0a15cf8>,
#  '进入': <gensim.models.keyedvectors.Vocab at 0x1d1b0a15e10>,
#  '服务': <gensim.models.keyedvectors.Vocab at 0x1d1b0a15f28>,
#  '用途': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1c080>,
#  '详细': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1c128>,
#  '了解': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1c1d0>,
#  '资料': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1c2e8>,
#  '请以': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1c390>,
#  '经办': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1c438>,
#  '行': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1c550>,
#  '个贷': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1c668>,
#  '部门': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1c780>,
#  '综合': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1c898>,
#  '提交': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1c9b0>,
#  '资料齐全': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1cac8>,
#  '审批': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1cbe0>,
#  '大约': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1ccf8>,
#  '#': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1ce10>,
#  '因为': <gensim.models.keyedvectors.Vocab at 0x1d1b0a1cf28>,
#  '中间': <gensim.models.keyedvectors.Vocab at 0x1d1b0a24080>,
#  '涉及': <gensim.models.keyedvectors.Vocab at 0x1d1b0a24198>,
#  '评估': <gensim.models.keyedvectors.Vocab at 0x1d1b0a242b0>,
#  '环节': <gensim.models.keyedvectors.Vocab at 0x1d1b0a243c8>,
#  '每个': <gensim.models.keyedvectors.Vocab at 0x1d1b0a244e0>,
#  '客户': <gensim.models.keyedvectors.Vocab at 0x1d1b0a245f8>,
#  '差异': <gensim.models.keyedvectors.Vocab at 0x1d1b0a24710>,
#  '能否': <gensim.models.keyedvectors.Vocab at 0x1d1b0a24828>,
#  '取消': <gensim.models.keyedvectors.Vocab at 0x1d1b0a24940>,
#  '相关': <gensim.models.keyedvectors.Vocab at 0x1d1b0a24a58>,
#  '信息': <gensim.models.keyedvectors.Vocab at 0x1d1b0a24b70>,
#  '客户经理': <gensim.models.keyedvectors.Vocab at 0x1d1b0a24c88>,
#  '【': <gensim.models.keyedvectors.Vocab at 0x1d1b0a24da0>,
#  '温馨': <gensim.models.keyedvectors.Vocab at 0x1d1b0a24eb8>,
#  '提示': <gensim.models.keyedvectors.Vocab at 0x1d1b0a24fd0>,
#  '】': <gensim.models.keyedvectors.Vocab at 0x1d1b0a29128>,
#  '一直': <gensim.models.keyedvectors.Vocab at 0x1d1b0a29240>,
#  '收到': <gensim.models.keyedvectors.Vocab at 0x1d1b0a29358>,
#  '回复': <gensim.models.keyedvectors.Vocab at 0x1d1b0a29470>,
#  '拨打': <gensim.models.keyedvectors.Vocab at 0x1d1b0a29588>,
#  '空中': <gensim.models.keyedvectors.Vocab at 0x1d1b0a296a0>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x1d1b0a297b8>,
#  '如果': <gensim.models.keyedvectors.Vocab at 0x1d1b0a298d0>,
#  '预借': <gensim.models.keyedvectors.Vocab at 0x1d1b0a29978>,
#  '现金': <gensim.models.keyedvectors.Vocab at 0x1d1b0a29a90>,
#  '一万五': <gensim.models.keyedvectors.Vocab at 0x1d1b0a29ba8>,
#  '就是': <gensim.models.keyedvectors.Vocab at 0x1d1b0a29cf8>,
#  '取': <gensim.models.keyedvectors.Vocab at 0x1d1b0a29e10>,
#  '登录': <gensim.models.keyedvectors.Vocab at 0x1d1b0a29f28>,
#  '网上银行': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2f080>,
#  '选择': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2f198>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2f2b0>,
#  '账户': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2f3c8>,
#  '管理': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2f4e0>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2f5f8>,
#  '查看': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2f710>,
#  '有没有': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2f828>,
#  '活期': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2f940>,
#  '随时': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2fa58>,
#  '提现': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2fb70>,
#  '产品': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2fc88>,
#  '更改': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2fda0>,
#  '预留': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2feb8>,
#  '手机号': <gensim.models.keyedvectors.Vocab at 0x1d1b0a2ffd0>,
#  '开户': <gensim.models.keyedvectors.Vocab at 0x1d1b0a37128>,
#  '人': <gensim.models.keyedvectors.Vocab at 0x1d1b0a371d0>,
#  '骗子': <gensim.models.keyedvectors.Vocab at 0x1d1b0a372e8>,
#  '虚假': <gensim.models.keyedvectors.Vocab at 0x1d1b0a37400>,
#  '网站': <gensim.models.keyedvectors.Vocab at 0x1d1b0a37518>,
#  '紧急': <gensim.models.keyedvectors.Vocab at 0x1d1b0a37630>,
#  '还款': <gensim.models.keyedvectors.Vocab at 0x1d1b0a37748>,
#  '渠道': <gensim.models.keyedvectors.Vocab at 0x1d1b0a377f0>,
#  '界面': <gensim.models.keyedvectors.Vocab at 0x1d1b0a37908>,
#  '底部': <gensim.models.keyedvectors.Vocab at 0x1d1b0a37a20>,
#  '点击': <gensim.models.keyedvectors.Vocab at 0x1d1b0a37b70>,
#  '→': <gensim.models.keyedvectors.Vocab at 0x1d1b0a37c88>,
#  '全部': <gensim.models.keyedvectors.Vocab at 0x1d1b0a37da0>,
#  '页面': <gensim.models.keyedvectors.Vocab at 0x1d1b0a37eb8>,
#  '最': <gensim.models.keyedvectors.Vocab at 0x1d1b0a37fd0>,
#  '上方': <gensim.models.keyedvectors.Vocab at 0x1d1b0a3d128>,
#  '一笔': <gensim.models.keyedvectors.Vocab at 0x1d1b0a3d240>,
#  '手动': <gensim.models.keyedvectors.Vocab at 0x1d1b0a3d358>,
#  '点': <gensim.models.keyedvectors.Vocab at 0x1d1b0a3d4a8>,
#  '立即': <gensim.models.keyedvectors.Vocab at 0x1d1b0a3d5c0>,
#  '收': <gensim.models.keyedvectors.Vocab at 0x1d1b0a3d6d8>,
#  '已经': <gensim.models.keyedvectors.Vocab at 0x1d1b0a3d7f0>,
#  '你好': <gensim.models.keyedvectors.Vocab at 0x1d1b0a3d908>,
#  '我想': <gensim.models.keyedvectors.Vocab at 0x1d1b0a3da20>,
#  '贷点款': <gensim.models.keyedvectors.Vocab at 0x1d1b0a3db38>,
#  '私代': <gensim.models.keyedvectors.Vocab at 0x1d1b0a3dc88>,
#  '包下': <gensim.models.keyedvectors.Vocab at 0x1d1b0a3ddd8>,
#  '不难': <gensim.models.keyedvectors.Vocab at 0x1d1b0a3df28>,
#  '呀': <gensim.models.keyedvectors.Vocab at 0x1d1b0a440b8>,
#  '网申': <gensim.models.keyedvectors.Vocab at 0x1d1b0a441d0>,
#  '一次': <gensim.models.keyedvectors.Vocab at 0x1d1b0a442e8>,
#  '过': <gensim.models.keyedvectors.Vocab at 0x1d1b0a44400>,
#  '只要': <gensim.models.keyedvectors.Vocab at 0x1d1b0a44518>,
#  '账单': <gensim.models.keyedvectors.Vocab at 0x1d1b0a44630>,
#  '算': <gensim.models.keyedvectors.Vocab at 0x1d1b0a44748>,
#  '但': <gensim.models.keyedvectors.Vocab at 0x1d1b0a44860>,
#  '日前': <gensim.models.keyedvectors.Vocab at 0x1d1b0a44978>,
#  '还清': <gensim.models.keyedvectors.Vocab at 0x1d1b0a44a90>,
#  '的话': <gensim.models.keyedvectors.Vocab at 0x1d1b0a44ba8>,
#  '哪些': <gensim.models.keyedvectors.Vocab at 0x1d1b0a44c50>,
#  '异地': <gensim.models.keyedvectors.Vocab at 0x1d1b0a44d68>,
#  '同行': <gensim.models.keyedvectors.Vocab at 0x1d1b0a44e80>,
#  '跨行': <gensim.models.keyedvectors.Vocab at 0x1d1b0a44f98>,
#  'ATM': <gensim.models.keyedvectors.Vocab at 0x1d1b0a47128>,
#  '取款': <gensim.models.keyedvectors.Vocab at 0x1d1b0a47240>,
#  '免': <gensim.models.keyedvectors.Vocab at 0x1d1b0a47358>,
#  '手续费': <gensim.models.keyedvectors.Vocab at 0x1d1b0a47470>,
#  '不免': <gensim.models.keyedvectors.Vocab at 0x1d1b0a47588>,
#  '放假': <gensim.models.keyedvectors.Vocab at 0x1d1b0a476d8>,
#  '开门': <gensim.models.keyedvectors.Vocab at 0x1d1b0a477f0>,
#  '营业': <gensim.models.keyedvectors.Vocab at 0x1d1b0a47940>,
#  '邮政储蓄': <gensim.models.keyedvectors.Vocab at 0x1d1b0a47a58>,
#  '急求': <gensim.models.keyedvectors.Vocab at 0x1d1b0a47ba8>,
#  '湖': <gensim.models.keyedvectors.Vocab at 0x1d1b0a47cf8>,
#  '衡': <gensim.models.keyedvectors.Vocab at 0x1d1b0a47e10>,
#  '附近': <gensim.models.keyedvectors.Vocab at 0x1d1b0a47f60>,
#  '金融': <gensim.models.keyedvectors.Vocab at 0x1d1b0a4f0b8>,
#  '熟练': <gensim.models.keyedvectors.Vocab at 0x1d1b0a4f1d0>,
#  '人士': <gensim.models.keyedvectors.Vocab at 0x1d1b0a4f320>,
#  '至于': <gensim.models.keyedvectors.Vocab at 0x1d1b0a4f438>,
#  '不会': <gensim.models.keyedvectors.Vocab at 0x1d1b0a4f550>,
#  '很': <gensim.models.keyedvectors.Vocab at 0x1d1b0a4f668>,
#  '说': <gensim.models.keyedvectors.Vocab at 0x1d1b0a4f780>,
#  '对': <gensim.models.keyedvectors.Vocab at 0x1d1b0a4f898>,
#  '日': <gensim.models.keyedvectors.Vocab at 0x1d1b0a4f9b0>,
#  '第二天': <gensim.models.keyedvectors.Vocab at 0x1d1b0a4fac8>,
#  '刷卡': <gensim.models.keyedvectors.Vocab at 0x1d1b0a4fbe0>,
#  '享受': <gensim.models.keyedvectors.Vocab at 0x1d1b0a4fcf8>,
#  '最长': <gensim.models.keyedvectors.Vocab at 0x1d1b0a4fe10>,
#  '免息期': <gensim.models.keyedvectors.Vocab at 0x1d1b0a4ff28>,
#  '购房': <gensim.models.keyedvectors.Vocab at 0x1d1b0a56080>,
#  '合同': <gensim.models.keyedvectors.Vocab at 0x1d1b0a56198>,
#  '上': <gensim.models.keyedvectors.Vocab at 0x1d1b0a562b0>,
#  '付款': <gensim.models.keyedvectors.Vocab at 0x1d1b0a56358>,
#  '方式': <gensim.models.keyedvectors.Vocab at 0x1d1b0a56470>,
#  '即使': <gensim.models.keyedvectors.Vocab at 0x1d1b0a56588>,
#  '更换': <gensim.models.keyedvectors.Vocab at 0x1d1b0a566a0>,
#  '变更': <gensim.models.keyedvectors.Vocab at 0x1d1b0a567b8>,
#  '下来': <gensim.models.keyedvectors.Vocab at 0x1d1b0a568d0>,
#  '拨付': <gensim.models.keyedvectors.Vocab at 0x1d1b0a569e8>,
#  '开发商': <gensim.models.keyedvectors.Vocab at 0x1d1b0a56b38>,
#  '个人': <gensim.models.keyedvectors.Vocab at 0x1d1b0a56c50>,
#  '昆': <gensim.models.keyedvectors.Vocab at 0x1d1b0a56d68>,
#  '做': <gensim.models.keyedvectors.Vocab at 0x1d1b0a56e80>,
#  '芝麻': <gensim.models.keyedvectors.Vocab at 0x1d1b0a56f98>,
#  '信用': <gensim.models.keyedvectors.Vocab at 0x1d1b0a590f0>,
#  '分': <gensim.models.keyedvectors.Vocab at 0x1d1b0a59208>,
#  '656': <gensim.models.keyedvectors.Vocab at 0x1d1b0a59358>,
#  '两万': <gensim.models.keyedvectors.Vocab at 0x1d1b0a594a8>,
#  '工作': <gensim.models.keyedvectors.Vocab at 0x1d1b0a595c0>,
#  '注册': <gensim.models.keyedvectors.Vocab at 0x1d1b0a59668>,
#  '网贷': <gensim.models.keyedvectors.Vocab at 0x1d1b0a59780>,
#  '准备': <gensim.models.keyedvectors.Vocab at 0x1d1b0a59898>,
#  '住房贷款': <gensim.models.keyedvectors.Vocab at 0x1d1b0a599b0>,
#  '满足': <gensim.models.keyedvectors.Vocab at 0x1d1b0a59ac8>,
#  '当地': <gensim.models.keyedvectors.Vocab at 0x1d1b0a59be0>,
#  '政策': <gensim.models.keyedvectors.Vocab at 0x1d1b0a59cf8>,
#  '年龄': <gensim.models.keyedvectors.Vocab at 0x1d1b0a59e10>,
#  '加': <gensim.models.keyedvectors.Vocab at 0x1d1b0a59f28>,
#  '年限': <gensim.models.keyedvectors.Vocab at 0x1d1b0a60080>,
#  '不得': <gensim.models.keyedvectors.Vocab at 0x1d1b0a60198>,
#  '超过': <gensim.models.keyedvectors.Vocab at 0x1d1b0a602b0>,
#  '70': <gensim.models.keyedvectors.Vocab at 0x1d1b0a60400>,
#  '同时': <gensim.models.keyedvectors.Vocab at 0x1d1b0a60518>,
#  '身份证明': <gensim.models.keyedvectors.Vocab at 0x1d1b0a60630>,
#  '收入': <gensim.models.keyedvectors.Vocab at 0x1d1b0a60748>,
#  '材料': <gensim.models.keyedvectors.Vocab at 0x1d1b0a60860>,
#  '具体情况': <gensim.models.keyedvectors.Vocab at 0x1d1b0a60978>,
#  '经理': <gensim.models.keyedvectors.Vocab at 0x1d1b0a60a90>,
#  '注': <gensim.models.keyedvectors.Vocab at 0x1d1b0a60ba8>,
#  '要求': <gensim.models.keyedvectors.Vocab at 0x1d1b0a60cc0>,
#  '如下': <gensim.models.keyedvectors.Vocab at 0x1d1b0a60dd8>,
#  '支出': <gensim.models.keyedvectors.Vocab at 0x1d1b0a60ef0>,
#  '与': <gensim.models.keyedvectors.Vocab at 0x1d1b0a66048>,
#  '比': <gensim.models.keyedvectors.Vocab at 0x1d1b0a66160>,
#  '控制': <gensim.models.keyedvectors.Vocab at 0x1d1b0a66278>,
#  '50%': <gensim.models.keyedvectors.Vocab at 0x1d1b0a663c8>,
#  '含': <gensim.models.keyedvectors.Vocab at 0x1d1b0a664e0>,
#  '以下': <gensim.models.keyedvectors.Vocab at 0x1d1b0a665f8>,
#  '所有': <gensim.models.keyedvectors.Vocab at 0x1d1b0a66710>,
#  '债务': <gensim.models.keyedvectors.Vocab at 0x1d1b0a66828>,
#  '55%': <gensim.models.keyedvectors.Vocab at 0x1d1b0a66978>,
#  '即': <gensim.models.keyedvectors.Vocab at 0x1d1b0a66ac8>,
#  '一半': <gensim.models.keyedvectors.Vocab at 0x1d1b0a66be0>,
#  '分行': <gensim.models.keyedvectors.Vocab at 0x1d1b0a66cf8>,
#  '规定': <gensim.models.keyedvectors.Vocab at 0x1d1b0a66e10>,
#  '欠款': <gensim.models.keyedvectors.Vocab at 0x1d1b0a66f28>,
#  '起诉': <gensim.models.keyedvectors.Vocab at 0x1d1b0a6c080>,
#  '办过': <gensim.models.keyedvectors.Vocab at 0x1d1b0a6c198>,
#  '天天': <gensim.models.keyedvectors.Vocab at 0x1d1b0a6c2b0>,
#  '律师': <gensim.models.keyedvectors.Vocab at 0x1d1b0a6c400>,
#  '事务所': <gensim.models.keyedvectors.Vocab at 0x1d1b0a6c550>,
#  '怎': <gensim.models.keyedvectors.Vocab at 0x1d1b0a6c6a0>,
#  'atm': <gensim.models.keyedvectors.Vocab at 0x1d1b0a6c828>,
#  '取款机': <gensim.models.keyedvectors.Vocab at 0x1d1b0a6c940>,
#  '同城': <gensim.models.keyedvectors.Vocab at 0x1d1b0a6ca58>,
#  '那里': <gensim.models.keyedvectors.Vocab at 0x1d1b0a6cb70>,
#  '这': <gensim.models.keyedvectors.Vocab at 0x1d1b0a6cc88>,
#  '意思': <gensim.models.keyedvectors.Vocab at 0x1d1b0a6cda0>,
#  '呢': <gensim.models.keyedvectors.Vocab at 0x1d1b0a6ceb8>,
#  '万': <gensim.models.keyedvectors.Vocab at 0x1d1b0a6cfd0>,
#  '房子': <gensim.models.keyedvectors.Vocab at 0x1d1b0a73128>,
#  '首付': <gensim.models.keyedvectors.Vocab at 0x1d1b0a73240>,
#  '供': <gensim.models.keyedvectors.Vocab at 0x1d1b0a73358>,
#  '为什么': <gensim.models.keyedvectors.Vocab at 0x1d1b0a73470>,
#  '充值': <gensim.models.keyedvectors.Vocab at 0x1d1b0a73588>,
#  '东西': <gensim.models.keyedvectors.Vocab at 0x1d1b0a736a0>,
#  '却': <gensim.models.keyedvectors.Vocab at 0x1d1b0a737b8>,
#  '账': <gensim.models.keyedvectors.Vocab at 0x1d1b0a738d0>,
#  '日常': <gensim.models.keyedvectors.Vocab at 0x1d1b0a739e8>,
#  '消费': <gensim.models.keyedvectors.Vocab at 0x1d1b0a73b38>,
#  '四千': <gensim.models.keyedvectors.Vocab at 0x1d1b0a73c50>,
#  '卡用': <gensim.models.keyedvectors.Vocab at 0x1d1b0a73da0>,
#  '按时': <gensim.models.keyedvectors.Vocab at 0x1d1b0a73ef0>,
#  '一卡通': <gensim.models.keyedvectors.Vocab at 0x1d1b0a79048>,
#  '交易': <gensim.models.keyedvectors.Vocab at 0x1d1b0a79160>,
#  '若有': <gensim.models.keyedvectors.Vocab at 0x1d1b0a79278>,
#  '疑问': <gensim.models.keyedvectors.Vocab at 0x1d1b0a79320>,
#  '反馈': <gensim.models.keyedvectors.Vocab at 0x1d1b0a79438>,
#  '自由职业': <gensim.models.keyedvectors.Vocab at 0x1d1b0a79550>,
#  '所谓': <gensim.models.keyedvectors.Vocab at 0x1d1b0a796a0>,
#  '三无': <gensim.models.keyedvectors.Vocab at 0x1d1b0a797b8>,
#  '人员': <gensim.models.keyedvectors.Vocab at 0x1d1b0a79908>,
#  '类人': <gensim.models.keyedvectors.Vocab at 0x1d1b0a79a20>,
#  '找': <gensim.models.keyedvectors.Vocab at 0x1d1b0a79b70>,
#  '特殊': <gensim.models.keyedvectors.Vocab at 0x1d1b0a79c88>,
#  '货币': <gensim.models.keyedvectors.Vocab at 0x1d1b0a79da0>,
#  '兑换': <gensim.models.keyedvectors.Vocab at 0x1d1b0a79eb8>,
#  '美元': <gensim.models.keyedvectors.Vocab at 0x1d1b0a79fd0>,
#  '人民币': <gensim.models.keyedvectors.Vocab at 0x1d1b0a7f128>,
#  '64': <gensim.models.keyedvectors.Vocab at 0x1d1b0a7f278>,
#  '44': <gensim.models.keyedvectors.Vocab at 0x1d1b0a7f400>,
#  '数据': <gensim.models.keyedvectors.Vocab at 0x1d1b0a7f518>,
#  '仅供参考': <gensim.models.keyedvectors.Vocab at 0x1d1b0a7f630>,
#  '时以': <gensim.models.keyedvectors.Vocab at 0x1d1b0a7f748>,
#  '成交价': <gensim.models.keyedvectors.Vocab at 0x1d1b0a7f860>,
#  '持卡': <gensim.models.keyedvectors.Vocab at 0x1d1b0a7f978>,
#  '过多': <gensim.models.keyedvectors.Vocab at 0x1d1b0a7fa90>,
#  '是不是': <gensim.models.keyedvectors.Vocab at 0x1d1b0a7fbe0>,
#  '批卡': <gensim.models.keyedvectors.Vocab at 0x1d1b0a7fcf8>,
#  '储蓄卡': <gensim.models.keyedvectors.Vocab at 0x1d1b0a7fe10>,
#  '转账': <gensim.models.keyedvectors.Vocab at 0x1d1b0a7ff28>,
#  '仍': <gensim.models.keyedvectors.Vocab at 0x1d1b0a84080>,
#  '查询卡': <gensim.models.keyedvectors.Vocab at 0x1d1b0a84198>,
#  '内': <gensim.models.keyedvectors.Vocab at 0x1d1b0a842e8>,
#  '余额': <gensim.models.keyedvectors.Vocab at 0x1d1b0a84400>,
#  '主页': <gensim.models.keyedvectors.Vocab at 0x1d1b0a84518>,
#  'www': <gensim.models.keyedvectors.Vocab at 0x1d1b0a84668>,
#  '右侧': <gensim.models.keyedvectors.Vocab at 0x1d1b0a84780>,
#  '大众版': <gensim.models.keyedvectors.Vocab at 0x1d1b0a84898>,
#  '输入': <gensim.models.keyedvectors.Vocab at 0x1d1b0a849b0>,
#  '密码': <gensim.models.keyedvectors.Vocab at 0x1d1b0a84ac8>,
#  '横排': <gensim.models.keyedvectors.Vocab at 0x1d1b0a84be0>,
#  '菜单': <gensim.models.keyedvectors.Vocab at 0x1d1b0a84c88>,
#  '即可': <gensim.models.keyedvectors.Vocab at 0x1d1b0a84da0>,
#  '60': <gensim.models.keyedvectors.Vocab at 0x1d1b0a84ef0>,
#  '以上': <gensim.models.keyedvectors.Vocab at 0x1d1b0a84f98>,
#  '老人': <gensim.models.keyedvectors.Vocab at 0x1d1b0a890f0>,
#  '方法': <gensim.models.keyedvectors.Vocab at 0x1d1b0a89240>,
#  '存': <gensim.models.keyedvectors.Vocab at 0x1d1b0a89358>,
#  '款': <gensim.models.keyedvectors.Vocab at 0x1d1b0a89470>,
#  '存款人': <gensim.models.keyedvectors.Vocab at 0x1d1b0a89518>,
#  '去世': <gensim.models.keyedvectors.Vocab at 0x1d1b0a89668>,
#  '由': <gensim.models.keyedvectors.Vocab at 0x1d1b0a897b8>,
#  '继承人': <gensim.models.keyedvectors.Vocab at 0x1d1b0a898d0>,
#  '自己': <gensim.models.keyedvectors.Vocab at 0x1d1b0a89a20>,
#  '继承权': <gensim.models.keyedvectors.Vocab at 0x1d1b0a89b38>,
#  '证明书': <gensim.models.keyedvectors.Vocab at 0x1d1b0a89c88>,
#  '法院': <gensim.models.keyedvectors.Vocab at 0x1d1b0a89d30>,
#  '判决书': <gensim.models.keyedvectors.Vocab at 0x1d1b0a89e48>,
#  '过户': <gensim.models.keyedvectors.Vocab at 0x1d1b0a89f98>,
#  '支取': <gensim.models.keyedvectors.Vocab at 0x1d1b0a8f0f0>,
#  '手续': <gensim.models.keyedvectors.Vocab at 0x1d1b0a8f208>,
#  '向': <gensim.models.keyedvectors.Vocab at 0x1d1b0a8f320>,
#  '户籍': <gensim.models.keyedvectors.Vocab at 0x1d1b0a8f438>,
#  '所在地': <gensim.models.keyedvectors.Vocab at 0x1d1b0a8f550>,
#  '储蓄机构': <gensim.models.keyedvectors.Vocab at 0x1d1b0a8f668>,
#  '公证处': <gensim.models.keyedvectors.Vocab at 0x1d1b0a8f7b8>,
#  '如是': <gensim.models.keyedvectors.Vocab at 0x1d1b0a8f908>,
#  '必须': <gensim.models.keyedvectors.Vocab at 0x1d1b0a8fa20>,
#  '境外': <gensim.models.keyedvectors.Vocab at 0x1d1b0a8fb38>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x1d1b0a8fc88>,
#  '~': <gensim.models.keyedvectors.Vocab at 0x1d1b0a8fda0>,
#  '经济': <gensim.models.keyedvectors.Vocab at 0x1d1b0a8feb8>,
#  '且': <gensim.models.keyedvectors.Vocab at 0x1d1b0a8ffd0>,
#  '良好': <gensim.models.keyedvectors.Vocab at 0x1d1b0a96128>,
#  '实际': <gensim.models.keyedvectors.Vocab at 0x1d1b0a96240>,
#  '必备': <gensim.models.keyedvectors.Vocab at 0x1d1b0a96358>,
#  '文件': <gensim.models.keyedvectors.Vocab at 0x1d1b0a96470>,
#  '复印件': <gensim.models.keyedvectors.Vocab at 0x1d1b0a96588>,
#  '证明文件': <gensim.models.keyedvectors.Vocab at 0x1d1b0a966a0>,
#  '将': <gensim.models.keyedvectors.Vocab at 0x1d1b0a967b8>,
#  '更': <gensim.models.keyedvectors.Vocab at 0x1d1b0a968d0>,
#  '有助于': <gensim.models.keyedvectors.Vocab at 0x1d1b0a969e8>,
#  '以及': <gensim.models.keyedvectors.Vocab at 0x1d1b0a96b00>,
#  '判断': <gensim.models.keyedvectors.Vocab at 0x1d1b0a96ba8>,
#  '用于': <gensim.models.keyedvectors.Vocab at 0x1d1b0a96cc0>,
#  '短期': <gensim.models.keyedvectors.Vocab at 0x1d1b0a96dd8>,
#  '资金周转': <gensim.models.keyedvectors.Vocab at 0x1d1b0a96ef0>,
#  '并': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9a080>,
#  '微信': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9a198>,
#  '中': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9a2b0>,
#  '搜': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9a3c8>,
#  '号码': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9a4e0>,
#  '中心': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9a5f8>,
#  '关注': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9a710>,
#  '来': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9a828>,
#  '寄送': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9a940>,
#  '进度': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9aa58>,
#  '分期付款': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9ab70>,
#  '金融公司': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9ac88>,
#  '还是': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9add8>,
#  '公司': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9ae80>,
#  '孩子': <gensim.models.keyedvectors.Vocab at 0x1d1b0a9af98>,
#  '存住': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa30f0>,
#  '时候': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa3240>,
#  '原件': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa3358>,
#  '按照': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa3470>,
#  '年满': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa3518>,
#  '至': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa3630>,
#  '具有': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa3748>,
#  '一': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa3860>,
#  '境内': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa3978>,
#  '居民': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa3a90>,
#  '申请人': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa3ba8>,
#  '军官证': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa3cc0>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa3dd8>,
#  'B': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa3ef0>,
#  '两项': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa8048>,
#  '港': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa8198>,
#  '回乡': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa82b0>,
#  '台': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa8400>,
#  '通行证': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa8518>,
#  '外籍人士': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa8630>,
#  '护照': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa8748>,
#  '居住': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa8860>,
#  '暂住证': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa8978>,
#  '明': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa8ac8>,
#  '工作证': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa8c18>,
#  '识别证': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa8d30>,
#  '加盖': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa8e80>,
#  '公章': <gensim.models.keyedvectors.Vocab at 0x1d1b0aa8f98>,
#  '最近': <gensim.models.keyedvectors.Vocab at 0x1d1b0aae0f0>,
#  '代发': <gensim.models.keyedvectors.Vocab at 0x1d1b0aae208>,
#  '工资卡': <gensim.models.keyedvectors.Vocab at 0x1d1b0aae320>,
#  '个人所得税': <gensim.models.keyedvectors.Vocab at 0x1d1b0aae438>,
#  '扣缴': <gensim.models.keyedvectors.Vocab at 0x1d1b0aae588>,
#  '凭证': <gensim.models.keyedvectors.Vocab at 0x1d1b0aae6a0>,
#  '开具': <gensim.models.keyedvectors.Vocab at 0x1d1b0aae7b8>,
#  '二': <gensim.models.keyedvectors.Vocab at 0x1d1b0aae860>,
#  '尽量': <gensim.models.keyedvectors.Vocab at 0x1d1b0aae978>,
#  '学历': <gensim.models.keyedvectors.Vocab at 0x1d1b0aaea90>,
#  '职称': <gensim.models.keyedvectors.Vocab at 0x1d1b0aaeba8>,
#  '专业': <gensim.models.keyedvectors.Vocab at 0x1d1b0aaecf8>,
#  '资格证书': <gensim.models.keyedvectors.Vocab at 0x1d1b0aaee10>,
#  '自有': <gensim.models.keyedvectors.Vocab at 0x1d1b0aaef60>,
#  '房产证': <gensim.models.keyedvectors.Vocab at 0x1d1b0ab60b8>,
#  '汽车': <gensim.models.keyedvectors.Vocab at 0x1d1b0ab61d0>,
#  '行驶证': <gensim.models.keyedvectors.Vocab at 0x1d1b0ab62e8>,
#  '定期存单': <gensim.models.keyedvectors.Vocab at 0x1d1b0ab6400>,
#  '现': <gensim.models.keyedvectors.Vocab at 0x1d1b0ab6518>,
#  '居住地': <gensim.models.keyedvectors.Vocab at 0x1d1b0ab6630>,
#  '水': <gensim.models.keyedvectors.Vocab at 0x1d1b0ab6780>,
#  '电': <gensim.models.keyedvectors.Vocab at 0x1d1b0ab6898>,
#  '煤气费': <gensim.models.keyedvectors.Vocab at 0x1d1b0ab69b0>,
#  '任一': <gensim.models.keyedvectors.Vocab at 0x1d1b0ab6b00>,
#  '单据': <gensim.models.keyedvectors.Vocab at 0x1d1b0ab6c18>,
#  '三期': <gensim.models.keyedvectors.Vocab at 0x1d1b0ab6d30>,
#  '流程': <gensim.models.keyedvectors.Vocab at 0x1d1b0ab6e80>,
#  '填写': <gensim.models.keyedvectors.Vocab at 0x1d1b0ab6f98>,
#  '申请表': <gensim.models.keyedvectors.Vocab at 0x1d1b0abb080>,
#  '寄': <gensim.models.keyedvectors.Vocab at 0x1d1b0abb198>,
#  '送给': <gensim.models.keyedvectors.Vocab at 0x1d1b0abb2b0>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x1d1b0abb3c8>,
#  '进行': <gensim.models.keyedvectors.Vocab at 0x1d1b0abb470>,
#  '拿到': <gensim.models.keyedvectors.Vocab at 0x1d1b0abb518>,
#  '卡片': <gensim.models.keyedvectors.Vocab at 0x1d1b0abb630>,
#  '函': <gensim.models.keyedvectors.Vocab at 0x1d1b0abb748>,
#  '展开': <gensim.models.keyedvectors.Vocab at 0x1d1b0abb860>,
#  '日元': <gensim.models.keyedvectors.Vocab at 0x1d1b0abb978>,
#  '折合': <gensim.models.keyedvectors.Vocab at 0x1d1b0abba90>,
#  '解绑': <gensim.models.keyedvectors.Vocab at 0x1d1b0abbbe0>,
#  '好像': <gensim.models.keyedvectors.Vocab at 0x1d1b0abbd30>,
#  '不行': <gensim.models.keyedvectors.Vocab at 0x1d1b0abbe48>,
#  '吧': <gensim.models.keyedvectors.Vocab at 0x1d1b0abbf60>,
#  '三': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac10b8>,
#  '哪儿': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac11d0>,
#  '借钱': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac12e8>,
#  '私人': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac1400>,
#  '｛': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac1518>,
#  '急': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac1668>,
#  '用钱': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac1780>,
#  '汽车贷款': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac1898>,
#  '怎样': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac19b0>,
#  '问题': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac1ac8>,
#  '简单': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac1be0>,
#  '～': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac1cf8>,
#  '套房': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac1e10>,
#  '认定': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac1f28>,
#  '借款人': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac7080>,
#  '家庭': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac7198>,
#  '包括': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac72b0>,
#  '配偶': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac73c8>,
#  '未成年': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac74e0>,
#  '子女': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac75f8>,
#  '房贷': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac7710>,
#  '次数': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac7828>,
#  '对于': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac7940>,
#  '利用': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac7a58>,
#  '购买': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac7b70>,
#  '首套': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac7c88>,
#  '自': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac7da0>,
#  '住房': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac7eb8>,
#  '如其': <gensim.models.keyedvectors.Vocab at 0x1d1b0ac7fd0>,
#  '人均': <gensim.models.keyedvectors.Vocab at 0x1d1b0acd160>,
#  '住房面积': <gensim.models.keyedvectors.Vocab at 0x1d1b0acd2b0>,
#  '低于': <gensim.models.keyedvectors.Vocab at 0x1d1b0acd400>,
#  '平均水平': <gensim.models.keyedvectors.Vocab at 0x1d1b0acd518>,
#  '再次': <gensim.models.keyedvectors.Vocab at 0x1d1b0acd668>,
#  '商业银行': <gensim.models.keyedvectors.Vocab at 0x1d1b0acd780>,
#  '比照': <gensim.models.keyedvectors.Vocab at 0x1d1b0acd898>,
#  '执行': <gensim.models.keyedvectors.Vocab at 0x1d1b0acd9e8>,
#  '应当': <gensim.models.keyedvectors.Vocab at 0x1d1b0acdb00>,
#  '房地产': <gensim.models.keyedvectors.Vocab at 0x1d1b0acdc18>,
#  '依据': <gensim.models.keyedvectors.Vocab at 0x1d1b0acdd30>,
#  '房屋': <gensim.models.keyedvectors.Vocab at 0x1d1b0acde48>,
#  '信息系统': <gensim.models.keyedvectors.Vocab at 0x1d1b0acdf60>,
#  '出具': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad30f0>,
#  '总面积': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad3208>,
#  '公积金': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad3358>,
#  '按': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad3470>,
#  '前款': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad3588>,
#  '应': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad36d8>,
#  '切实': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad37f0>,
#  '履行': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad3940>,
#  '告知': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad3a58>,
#  '义务': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad3b70>,
#  '诚信': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad3cc0>,
#  '原则': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad3e10>,
#  '真实': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad3f28>,
#  '房产': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad9080>,
#  '税收': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad9198>,
#  '凡': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad92e8>,
#  '发现': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad9438>,
#  '填报': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad9550>,
#  '其': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad96a0>,
#  '信贷': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad97b8>,
#  '被': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad98d0>,
#  '查实': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad99e8>,
#  '再': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad9b38>,
#  '采信': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad9c50>,
#  '20w': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad9dd8>,
#  '透支': <gensim.models.keyedvectors.Vocab at 0x1d1b0ad9f28>,
#  '好处': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae0080>,
#  '3000': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae01d0>,
#  '完': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae02e8>,
#  '及时': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae0390>,
#  '久': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae04a8>,
#  '刚': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae05f8>,
#  '不要': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae0710>,
#  '成': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae0828>,
#  '想要': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae0940>,
#  '提前': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae0a58>,
#  '让': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae0b70>,
#  '别人': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae0c18>,
#  '代办': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae0d30>,
#  '春风': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae0e48>,
#  '十里': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae0f98>,
#  '不如': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae7128>,
#  '取现': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae7240>,
#  '24': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae7390>,
#  '小时': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae7438>,
#  '会上': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae7550>,
#  '借到': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae7668>,
#  '一天': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae7780>,
#  '出现': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae7898>,
#  '客服热线': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae79b0>,
#  '400820': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae7a90>,
#  '贰': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae7be0>,
#  '拾': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae7cf8>,
#  '贰仟': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae7e48>,
#  '肆佰': <gensim.models.keyedvectors.Vocab at 0x1d1b0ae7f98>,
#  '捌': <gensim.models.keyedvectors.Vocab at 0x1d1b0aeb128>,
#  '中文': <gensim.models.keyedvectors.Vocab at 0x1d1b0aeb278>,
#  '大写': <gensim.models.keyedvectors.Vocab at 0x1d1b0aeb3c8>,
#  '应用': <gensim.models.keyedvectors.Vocab at 0x1d1b0aeb4e0>,
#  '正楷': <gensim.models.keyedvectors.Vocab at 0x1d1b0aeb5f8>,
#  '行书': <gensim.models.keyedvectors.Vocab at 0x1d1b0aeb748>,
#  '如壹': <gensim.models.keyedvectors.Vocab at 0x1d1b0aeb898>,
#  '壹': <gensim.models.keyedvectors.Vocab at 0x1d1b0aeb9e8>,
#  '叁': <gensim.models.keyedvectors.Vocab at 0x1d1b0aebb38>,
#  '肆': <gensim.models.keyedvectors.Vocab at 0x1d1b0aebc88>,
#  '伍': <gensim.models.keyedvectors.Vocab at 0x1d1b0aebdd8>,
#  '陆': <gensim.models.keyedvectors.Vocab at 0x1d1b0aebf28>,
#  '柒': <gensim.models.keyedvectors.Vocab at 0x1d1b0af30b8>,
#  '玖': <gensim.models.keyedvectors.Vocab at 0x1d1b0af3208>,
#  '佰': <gensim.models.keyedvectors.Vocab at 0x1d1b0af3358>,
#  '仟': <gensim.models.keyedvectors.Vocab at 0x1d1b0af34a8>,
#  '亿': <gensim.models.keyedvectors.Vocab at 0x1d1b0af35f8>,
#  '角': <gensim.models.keyedvectors.Vocab at 0x1d1b0af3710>,
#  '零': <gensim.models.keyedvectors.Vocab at 0x1d1b0af3860>,
#  '整': <gensim.models.keyedvectors.Vocab at 0x1d1b0af3978>,
#  '正': <gensim.models.keyedvectors.Vocab at 0x1d1b0af3ac8>,
#  '字样': <gensim.models.keyedvectors.Vocab at 0x1d1b0af3c18>,
#  '两': <gensim.models.keyedvectors.Vocab at 0x1d1b0af3d68>,
#  '四': <gensim.models.keyedvectors.Vocab at 0x1d1b0af3e80>,
#  '五': <gensim.models.keyedvectors.Vocab at 0x1d1b0af3f98>,
#  '六': <gensim.models.keyedvectors.Vocab at 0x1d1b0af8080>,
#  '八': <gensim.models.keyedvectors.Vocab at 0x1d1b0af8198>,
#  '九': <gensim.models.keyedvectors.Vocab at 0x1d1b0af82e8>,
#  '十': <gensim.models.keyedvectors.Vocab at 0x1d1b0af8438>,
#  '念': <gensim.models.keyedvectors.Vocab at 0x1d1b0af8588>,
#  '毛': <gensim.models.keyedvectors.Vocab at 0x1d1b0af86d8>,
#  '另': <gensim.models.keyedvectors.Vocab at 0x1d1b0af8828>,
#  '0': <gensim.models.keyedvectors.Vocab at 0x1d1b0af8940>,
#  '自造': <gensim.models.keyedvectors.Vocab at 0x1d1b0af8a58>,
#  '简化字': <gensim.models.keyedvectors.Vocab at 0x1d1b0af8ba8>,
#  '书写': <gensim.models.keyedvectors.Vocab at 0x1d1b0af8cf8>,
#  '繁体字': <gensim.models.keyedvectors.Vocab at 0x1d1b0af8e48>,
#  '圆': <gensim.models.keyedvectors.Vocab at 0x1d1b0af8f98>,
#  '"': <gensim.models.keyedvectors.Vocab at 0x1d1b0afd128>,
#  '为止': <gensim.models.keyedvectors.Vocab at 0x1d1b0afd240>,
#  '之后': <gensim.models.keyedvectors.Vocab at 0x1d1b0afd358>,
#  '应写': <gensim.models.keyedvectors.Vocab at 0x1d1b0afd470>,
#  '字': <gensim.models.keyedvectors.Vocab at 0x1d1b0afd5c0>,
#  '不写': <gensim.models.keyedvectors.Vocab at 0x1d1b0afd6a0>,
#  '后面': <gensim.models.keyedvectors.Vocab at 0x1d1b0afd7f0>,
#  '前应': <gensim.models.keyedvectors.Vocab at 0x1d1b0afd908>,
#  '标明': <gensim.models.keyedvectors.Vocab at 0x1d1b0afda58>,
#  '紧接': <gensim.models.keyedvectors.Vocab at 0x1d1b0afdba8>,
#  '留有': <gensim.models.keyedvectors.Vocab at 0x1d1b0afdcf8>,
#  '空白': <gensim.models.keyedvectors.Vocab at 0x1d1b0afde48>,
#  '前未印': <gensim.models.keyedvectors.Vocab at 0x1d1b0afdf98>,
#  '加填': <gensim.models.keyedvectors.Vocab at 0x1d1b0b03128>,
#  '三字': <gensim.models.keyedvectors.Vocab at 0x1d1b0b03278>,
#  '票据': <gensim.models.keyedvectors.Vocab at 0x1d1b0b033c8>,
#  '结算': <gensim.models.keyedvectors.Vocab at 0x1d1b0b034e0>,
#  '栏内': <gensim.models.keyedvectors.Vocab at 0x1d1b0b035f8>,
#  '预印': <gensim.models.keyedvectors.Vocab at 0x1d1b0b03748>,
#  '书面': <gensim.models.keyedvectors.Vocab at 0x1d1b0b03898>,
#  '挂失': <gensim.models.keyedvectors.Vocab at 0x1d1b0b039b0>,
#  '持': <gensim.models.keyedvectors.Vocab at 0x1d1b0b03ac8>,
#  '前往': <gensim.models.keyedvectors.Vocab at 0x1d1b0b03be0>,
#  '任意': <gensim.models.keyedvectors.Vocab at 0x1d1b0b03cf8>,
#  '时': <gensim.models.keyedvectors.Vocab at 0x1d1b0b03e10>,
#  '出示': <gensim.models.keyedvectors.Vocab at 0x1d1b0b03f28>,
#  '双人': <gensim.models.keyedvectors.Vocab at 0x1d1b0b09080>,
#  '后续': <gensim.models.keyedvectors.Vocab at 0x1d1b0b09198>,
#  '由卡主': <gensim.models.keyedvectors.Vocab at 0x1d1b0b092b0>,
#  '不可': <gensim.models.keyedvectors.Vocab at 0x1d1b0b09400>,
#  '凭': <gensim.models.keyedvectors.Vocab at 0x1d1b0b09518>,
#  '指定': <gensim.models.keyedvectors.Vocab at 0x1d1b0b09630>,
#  '领卡': <gensim.models.keyedvectors.Vocab at 0x1d1b0b09748>,
#  '何时': <gensim.models.keyedvectors.Vocab at 0x1d1b0b09860>,
#  '多元化': <gensim.models.keyedvectors.Vocab at 0x1d1b0b099b0>,
#  '准时': <gensim.models.keyedvectors.Vocab at 0x1d1b0b09b00>,
#  '户口本': <gensim.models.keyedvectors.Vocab at 0x1d1b0b09c50>,
#  '消除': <gensim.models.keyedvectors.Vocab at 0x1d1b0b09d68>,
#  '这是': <gensim.models.keyedvectors.Vocab at 0x1d1b0b09e80>,
#  '跟着': <gensim.models.keyedvectors.Vocab at 0x1d1b0b09f28>,
#  '一辈子': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0d0b8>,
#  '要点': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0d208>,
#  '哪': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0d358>,
#  '借': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0d400>,
#  '求': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0d518>,
#  '帮助': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0d5c0>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0d710>,
#  '闲置': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0d7b8>,
#  '资金': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0d898>,
#  '怎么': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0d9b0>,
#  '合适': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0dac8>,
#  '想办': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0dbe0>,
#  '步': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0dcf8>,
#  '工作日内': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0de48>,
#  '建议': <gensim.models.keyedvectors.Vocab at 0x1d1b0b0df60>,
#  '官网': <gensim.models.keyedvectors.Vocab at 0x1d1b0b130b8>,
#  '在线': <gensim.models.keyedvectors.Vocab at 0x1d1b0b131d0>,
#  '国庆': <gensim.models.keyedvectors.Vocab at 0x1d1b0b132e8>,
#  '前': <gensim.models.keyedvectors.Vocab at 0x1d1b0b13438>,
#  '快递': <gensim.models.keyedvectors.Vocab at 0x1d1b0b13550>,
#  '坑': <gensim.models.keyedvectors.Vocab at 0x1d1b0b13668>,
#  '软件': <gensim.models.keyedvectors.Vocab at 0x1d1b0b137b8>,
#  '学生': <gensim.models.keyedvectors.Vocab at 0x1d1b0b138d0>,
#  '阿': <gensim.models.keyedvectors.Vocab at 0x1d1b0b139e8>,
#  '欠': <gensim.models.keyedvectors.Vocab at 0x1d1b0b13b38>,
#  '1.5': <gensim.models.keyedvectors.Vocab at 0x1d1b0b13c88>,
#  '暂时': <gensim.models.keyedvectors.Vocab at 0x1d1b0b13dd8>,
#  '没钱': <gensim.models.keyedvectors.Vocab at 0x1d1b0b13ef0>,
#  '怎么样': <gensim.models.keyedvectors.Vocab at 0x1d1b0b18048>,
#  '意味着': <gensim.models.keyedvectors.Vocab at 0x1d1b0b18160>,
#  '65': <gensim.models.keyedvectors.Vocab at 0x1d1b0b182e8>,
#  '自然人': <gensim.models.keyedvectors.Vocab at 0x1d1b0b18400>,
#  '期限': <gensim.models.keyedvectors.Vocab at 0x1d1b0b18518>,
#  '稳定': <gensim.models.keyedvectors.Vocab at 0x1d1b0b18630>,
#  '职业': <gensim.models.keyedvectors.Vocab at 0x1d1b0b18748>,
#  '按期': <gensim.models.keyedvectors.Vocab at 0x1d1b0b18860>,
#  '偿付': <gensim.models.keyedvectors.Vocab at 0x1d1b0b18978>,
#  '征信': <gensim.models.keyedvectors.Vocab at 0x1d1b0b18a90>,
#  '无': <gensim.models.keyedvectors.Vocab at 0x1d1b0b18ba8>,
#  '不良': <gensim.models.keyedvectors.Vocab at 0x1d1b0b18cc0>,
#  '拒绝': <gensim.models.keyedvectors.Vocab at 0x1d1b0b18d68>,
#  '大神': <gensim.models.keyedvectors.Vocab at 0x1d1b0b18e80>,
#  '办办': <gensim.models.keyedvectors.Vocab at 0x1d1b0b18f98>,
#  '业务员': <gensim.models.keyedvectors.Vocab at 0x1d1b0b20128>,
#  '认识': <gensim.models.keyedvectors.Vocab at 0x1d1b0b201d0>,
#  '靠': <gensim.models.keyedvectors.Vocab at 0x1d1b0b202e8>,
#  '谱': <gensim.models.keyedvectors.Vocab at 0x1d1b0b20400>,
#  '定期': <gensim.models.keyedvectors.Vocab at 0x1d1b0b20518>,
#  '朋友': <gensim.models.keyedvectors.Vocab at 0x1d1b0b20630>,
#  '其实': <gensim.models.keyedvectors.Vocab at 0x1d1b0b20748>,
#  '茄子': <gensim.models.keyedvectors.Vocab at 0x1d1b0b20860>,
#  '支付': <gensim.models.keyedvectors.Vocab at 0x1d1b0b209b0>,
#  'APP': <gensim.models.keyedvectors.Vocab at 0x1d1b0b20b00>,
#  '上面': <gensim.models.keyedvectors.Vocab at 0x1d1b0b20c18>,
#  '一键': <gensim.models.keyedvectors.Vocab at 0x1d1b0b20d30>,
#  '好多': <gensim.models.keyedvectors.Vocab at 0x1d1b0b20e80>,
#  ...}

# %%
import pandas as pd
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

iris = datasets.load_iris()
parameters = {'kernel':('linear', 'rbf'), 'C':[1, 2, 4], 'gamma':[0.125, 0.25, 0.5 ,1, 2, 4]}
svr = svm.SVC()
clf = GridSearchCV(svr, parameters, n_jobs=-1)
clf.fit(iris.data, iris.target)
cv_result = pd.DataFrame.from_dict(clf.cv_results_)
with open('cv_result.csv','w') as f:
    cv_result.to_csv(f)
    
print('The parameters of the best model are: ')
print(clf.best_params_)

y_pred = clf.predict(iris.data)
print(classification_report(y_true=iris.target, y_pred=y_pred))
# Out:
# D:\Tools\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# The parameters of the best model are:
# {'C': 2, 'gamma': 0.125, 'kernel': 'linear'}
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       1.00      0.94      0.97        50
#            2       0.94      1.00      0.97        50
#
#    micro avg       0.98      0.98      0.98       150
#    macro avg       0.98      0.98      0.98       150
# weighted avg       0.98      0.98      0.98       150
# D:\Tools\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# D:\Tools\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# D:\Tools\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# D:\Tools\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# D:\Tools\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
clf.best_params_
# Out:
# {'C': 2, 'gamma': 0.125, 'kernel': 'linear'}
